# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
import pandas as pd
import os
# Out:
# Mounted at /content/drive

# %%
# Putting all the features that PubMed returns into a pandas dataframe ...

from pathlib import Path
csv_file = Path("/content/drive/MyDrive/initial_df.csv")

if csv_file.is_file():
  df = pd.read_csv(str(csv_file.resolve()))
  df = df.astype(str)
  print( "Initial Dataframe retrieved from \"initial_df.csv\"!" )
else:
  # Show number of duplicated PMID values:

  import glob

  csv_df = -1

  # for file in glob.glob("/content/drive/MyDrive/changed_CD012768*.csv"): # tested the whole thing only on "changed_CD012768.csv" and "changed_CD012768 (copy).csv" ...
  for file in glob.glob("/content/drive/MyDrive/DTA/*/*.csv"):
    filename = os.path.basename(file)
    temp_df = pd.read_csv(file, index_col=0)
    temp_df[ "Filename" ]=filename
    if ( "'int'" in str(type(csv_df)) ):
      csv_df = temp_df.copy()
    else:
      csv_df = pd.concat([csv_df, temp_df], axis=0, ignore_index=True)
    print( "All " + str(temp_df.shape[0]) + " rows of \"" + file + "\" were added to \"csv_df\" .. " )
    print( "\"csv_df\" has " + str(csv_df.shape[0]) + " rows ..." )
    csv_df = csv_df.drop_duplicates()
    print( "\"csv_df\" has " + str(csv_df.shape[0]) + " rows after duplicate removal ..." )
    print( "===========" )

  print( "Total count of of \"PMID\" values:\t" + str(csv_df.shape[0]) )
  print( "Duplicate count of \"PMID\" column:\t" + str(csv_df.duplicated(subset="PMID").sum()) )

  pmids = list(csv_df["PMID"])
  pmids = list(dict.fromkeys(pmids)) # remove duplicate PMID values
  print( "Number of distinct \"PMID\" values:\t" + str(len(pmids)) )


  # Shows duplicate count for each column

  # for column in csv_df.columns.values:
  #   print( "Duplicate count of \"" + column + "\" column: ", end='' )
  #   print( csv_df.duplicated(subset=column).sum() )





  # Imports and so on ...

  # !pip install metapub
  import numpy as np
  pd.set_option('display.max_columns', None) # so it prints all the dataframe columns ...
  from metapub import PubMedFetcher

  from metapub import PubMedFetcher
  import json
  fetch = PubMedFetcher()

  def hasmethod(obj, name): # the functions returned should be stored separately ... may be used to return something that is not in the other properties later on ...
      return hasattr(obj, name) and ( "method" in str(type(getattr(obj, name))) )

  all_article_data=[]
  column_names=[]
  function_names=[]
  for i in range( 0, len( pmids ) ):
    try:
      article = fetch.article_by_pmid(pmids[i])
      article_data = {}
      for attr in dir( article ):
        if ( i == 0 ):
          if ( not hasmethod( article, str( attr ) ) ):
              column_names.append( attr )
          else:
              function_names.append( attr )
        if ( not hasmethod( article, str( attr ) ) ):
          article_data[ attr ] = getattr(article, attr)
      all_article_data.append( article_data )
    except:
      pass

  df = pd.DataFrame( all_article_data, columns=column_names )
  df.to_csv("/content/drive/MyDrive/initial_df.csv", encoding='utf-8', index=False)
  print( "Initial Dataframe saved to \"initial_df.csv\"!" )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c0232df4e2b1> in <cell line: 0>()
#       5
#       6 if csv_file.is_file():
# ----> 7   df = pd.read_csv(str(csv_file.resolve()))
#       8   df = df.astype(str)
#       9   print( "Initial Dataframe retrieved from \"initial_df.csv\"!" )
#
# NameError: name 'pd' is not defined

# %%
# Dropping all columns that only have NaN or fully identical values ...

count_row = df.shape[0]  # Gives number of rows
freq_df=df.describe().loc[['freq']]
count_df=df.describe().loc[['count']]
for column in freq_df:
    if ( freq_df[column].iloc[0] == count_df[column].iloc[0] ):
      df = df.drop(column, axis=1)
    if ( pd.isna(freq_df[column].iloc[0]) ):
      df = df.drop(column, axis=1)

# %%
# This whole thing was a xml to json conversion that barely helped at all ... better to just parse the xml ...

# import xml.etree.ElementTree as ET
# all_json_xml_tags=[]

# def extract_row_xml_tags(row):
#   xml_tree = ET.ElementTree(ET.fromstring(row["xml"]))
#   all_xml_tags = []
#   for elem in xml_tree.iter():
#       all_xml_tags.append(elem.tag)
#   all_xml_tags = list(set(all_xml_tags))
#   # print(all_xml_tags)

#   xml_tag_json={}
#   for elem in all_xml_tags:
#     final_arr=[]
#     arr = xml_tree.findall(".//"+elem)
#     for i in arr:
#       # print( ET.tostring( i, encoding='unicode' ) )
#       final_arr.append( ET.tostring(i, encoding='unicode') )
#     xml_tag_json[ elem ] = final_arr

#   json_string = json.dumps( xml_tag_json )
#   return json_string

# df["json_xml"] = df.apply(extract_row_xml_tags, axis=1)

# import json
# print( json.dumps(df.iloc[0]["json_xml"], indent=4) )

# %%
# This reveals that the content feature is contained in the xml feature (they are both xml representations of the same thing)

# from lxml import etree
# content=df.iloc[0]["content"]
# etree.tostring(content, pretty_print=True)

# %%
# Removing more useless columns and adding some new ones to better describe the data ...

remove_columns=[ "__dict__", "pii", "author1_lastfm", "author_list", "authors_str", "author1_last_fm", "content", "citation_html", "pages", "first_page", "last_page" ]
# pcim / doi are redundant as they are found in the urls too ... yet they were not removed for now ...
# pii contains the issn and other things ... no way to retrieve article though "Publisher Item Identifier", unless you go to the actual publisher's website ...

if "author1_last_fm" in df.columns:
  df["author_first"]=df["author1_last_fm"]

# if "pmc" in df.columns: # so as to parse the webpage like with the pubmed site ...
#   df['pmc_url']="https://pmc.ncbi.nlm.nih.gov/articles/PMC"+str(df['pmc'])+"/"




# Uncomment this to keep the doi in an url ... yet, each doi url points to a different 2nd domain, which is NOT the same for all articles, meaning that it is not easy to get data from it (website structures differ) ...

# if "doi" in df.columns: # so as to parse the webpage like with the pubmed site ...
#   df["doi_url"]="https://doi.org/"+df["doi"]


for i in remove_columns:
  if i in df.columns:
    df = df.drop(i, axis=1)
df.describe()


# Choose one of the following methods for formatting xml in a visible way ... Quite sure the first one has no bugs ...

# import xml.dom.minidom
# def restyle_xml(row):
#   return xml.dom.minidom.parseString(row["xml"]).toprettyxml()
# df['xml'] = df.apply(restyle_xml, axis=1)
# print( df.iloc[0]["xml"] )

# from lxml import etree
# def restyle_xml(row):
#   x = etree.fromstring(row["xml"])
#   return etree.tostring(x, pretty_print=True)
# df['xml'] = df.apply(restyle_xml, axis=1)
# Out:
#                                                  abstract authors chemicals  \
# count                                               26806   26806     26806
# unique                                              26797   26376      5887
# top     CURRENT DIAGNOSTIC METHODS: Helicobacter pylor...      []        {}
# freq                                                    2      10     17051
#
#                                                  citation    doi  \
# count                                               26806  26806
# unique                                              26806  21320
# top     Peter JG, et al. The diagnostic accuracy of ur...    nan
# freq                                                    1   5487
#
#                                                   history       issn  issue  \
# count                                               26806      26806  26806
# unique                                              19048       4193    470
# top     {'pubmed': datetime.datetime(1996, 1, 1, 0, 0)...  1573-3432      1
# freq                                                  100        489   3555
#
#                       journal keywords  ...    pmc      pmid  \
# count                   26806    26806  ...  26806     26806
# unique                   3323     2491  ...   4388     26806
# top     Spine (Phila Pa 1976)       []  ...    nan  22815718
# freq                      583    24312  ...  22419         1
#
#                      publication_types  \
# count                            26806
# unique                             528
# top     {'D016428': 'Journal Article'}
# freq                              7777
#
#                                               title  \
# count                                         26806
# unique                                        26717
# top     Diagnosis of Helicobacter pylori infection.
# freq                                             10
#
#                                              url volume volume_issue  \
# count                                      26806  26806        26806
# unique                                     26806    639         4324
# top     https://ncbi.nlm.nih.gov/pubmed/22815718     18          nan
# freq                                           1    472          208
#
#                                                       xml   year author_first
# count                                               26806  26806        26806
# unique                                              26806     49        20670
# top     b'<?xml version="1.0" ?>\n<!DOCTYPE PubmedArti...   2013   Gisbert JP
# freq                                                    1   1891           72
#
# [4 rows x 21 columns]

# %%
df.to_csv("/content/drive/MyDrive/checkpoint_1_df.csv", encoding='utf-8', index=False)

# %%
from ast import literal_eval
df['xml'] = df['xml'].apply(literal_eval) # converts string to list ... only way ...

# %%
# Getting references with ids from the "xml" property that PubMed returned ...

import xml.etree.ElementTree as ET

def get_references(row):
  xml_tree = ET.ElementTree(ET.fromstring(row["xml"]))
  have_citation=0
  for elem in xml_tree.iter():
    if ( "'ReferenceList'" in str( elem ) ):
      have_citation=1
      break

  # <Reference>
  # 	<Citation>REFERENCE ARTICLE TITLE</Citation>
  # 	<ArticleIdList>
  # 		<ArticleId IdType="pmc">PMC ID</ArticleId>
  # 		<ArticleId IdType="pubmed">PUBMED ID</ArticleId>
  # 	</ArticleIdList>
  # </Reference>

  all_citations=[]
  if ( have_citation == 1 ):
    ref_list=xml_tree.find(".//ReferenceList")
    refs=ref_list.findall(".//Reference")
    for ref in refs:
      citation_json={}
      for citation in ref.findall( ".//Citation" ):
        citation_json[ "citation" ] = citation.text
      article_id_list=ref.find( ".//ArticleIdList" )

      article_id_json={}
      if ( article_id_list != None ):
        for article_id in article_id_list.findall( ".//ArticleId" ):
          article_id_json[ article_id.attrib['IdType'] ] = article_id.text

      citation_json[ "article_ids" ] = article_id_json
      all_citations.append( citation_json )

  return json.dumps( all_citations )

df['references'] = df.apply(get_references, axis=1)

# %%
citation_df = df[["pmid", "references"]]
citation_df = citation_df.astype(str)
citation_df = citation_df[citation_df["references"] != "[]" ]
citation_df.to_csv("/content/drive/MyDrive/citations.csv", encoding='utf-8', index=False)

# %%
from ast import literal_eval
df['keywords'] = df['keywords'].apply(literal_eval) # converts string to list ... only way ...

# %%
# Here, since most pmids do NOT have any keywords, some are generated for each of them ...

# This is done by:
#   0. removing all the common words from the title (done using lists of common words from wiki)
#   1. going though all the keywords that were found (from the articles that had them), to make a list of non-generated keywords/phrases
#   2. adding non-generated keywords/phrases to an article without keywords if they appear in its title
#   3. adding the final non-common title words to the keywords (the ones that remained = were not common and were not in non-generated keywords/phrases)
# (for everything to function properly everything has to be lowercase)

# All the common words are saved to a csv file, for easy access ...

from pathlib import Path
csv_file = Path("/content/drive/MyDrive/stop_words.csv")

if csv_file.is_file():
  print( "Stop words retrieved from \"stop_words.csv\"!" )
  stop_words = list(pd.read_csv(str(csv_file.resolve()))["word"])
else:
  print( "Stop words were re-generated and saved to \"stop_words.csv\"!" )
  import nltk
  nltk.download('stopwords')
  stop_words = list(stopwords.words("english"))

  print( "length before wiki: " + str( len(stop_words) ) )
  import urllib.request
  from bs4 import BeautifulSoup

  fp = urllib.request.urlopen("https://en.wiktionary.org/wiki/Wiktionary:Frequency_lists/English/Wikipedia_(2016)")
  mybytes = fp.read()
  html_page = mybytes.decode("utf8")
  fp.close()
  soup = BeautifulSoup(html_page)
  all_p = soup.find_all("p")
  word_p = []
  for p in all_p:
    if ( len( p.find_all() ) > 100 ):
      word_p.append( p )

  for p in word_p:
    word_a = list( p.find_all() );
    # print( word_a )
    for a in word_a:
        stop_words.append( a.text.lower() )

  print( "length after wiki 1: " + str( len(stop_words) ) )
  stop_words = list(dict.fromkeys(stop_words)) # removing duplicate words
  print( "length after wiki 1 (duplicates removed): " + str( len(stop_words) ) )
  fp = urllib.request.urlopen("https://en.wiktionary.org/wiki/Wiktionary:Frequency_lists/PG/2005/10/1-10000")
  mybytes = fp.read()
  html_page = mybytes.decode("utf8")
  fp.close()
  soup = BeautifulSoup(html_page)
  all_p = soup.find_all("p")
  word_p = []
  for p in all_p:
    if ( len( p.find_all() ) > 100 ):
      word_p.append( p )

  for p in word_p:
    word_a = list( p.find_all("a"));
    # print( word_a )
    for a in word_a:
      stop_words.append( a["title"].lower() )

  print( "length after wiki 2: " + str( len(stop_words) ) )
  stop_words = list(dict.fromkeys(stop_words)) # removing duplicate words
  print( "length after wiki 2 (duplicates removed): " + str( len(stop_words) ) )

  def add_more_stop_words (page):
    global stop_words
    fp = urllib.request.urlopen("https://en.wiktionary.org/wiki/Wiktionary:Frequency_lists/TV/2006/"+page)
    mybytes = fp.read()
    html_page = mybytes.decode("utf8")
    fp.close()
    soup = BeautifulSoup(html_page)
    all_td = soup.find_all("td")
    for td in all_td:
      if ( td.find("a") != None ):
        stop_words.append( td.find("a")["title"].lower() )
    stop_words = list(dict.fromkeys(stop_words)) # removing duplicate words


  for page_iter in range( 0, 10000, 1000 ):
    # print( str( page_iter + 1 ) + "-" + str( page_iter + 1000 ) )
    add_more_stop_words( str( page_iter + 1 ) + "-" + str( page_iter + 1000 ) )
  for page_iter in range( 10000, 20000, 2000 ):
    # print( str( page_iter + 1 ) + "-" + str( page_iter + 2000 ) )
    add_more_stop_words( str( page_iter + 1 ) + "-" + str( page_iter + 2000 ) )
  add_more_stop_words( "40001-41284" )


  print( "length after wiki 3: " + str( len(stop_words) ) )
  stop_words = list(dict.fromkeys(stop_words)) # removing duplicate words
  print( "length after wiki 3 (duplicates removed): " + str( len(stop_words) ) )

  stop_words_df = pd.DataFrame( stop_words, columns=["word"] )
  stop_words_df.to_csv("/content/drive/MyDrive/stop_words.csv", encoding='utf-8', index=False)



def get_keywords(sentence):
  words = sentence.lower().split()
  filtered_words = [word for word in words if word not in stop_words]
  uncommon_words = ' '.join(filtered_words)

  valid_characters = set('abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ\- /_0123456789')
  # as such: "!"#$%&'()*+,.:;<=>?@[\\]^`{|}~" are now allowed of keyword names

  final_string = ''.join(c for c in uncommon_words if c in valid_characters)
  return final_string



count_empty=0
count_non_empty=0
non_generated_keywords=[]
def determine_keywords(row):
  global non_generated_keywords
  if ( row["keywords"] != [] ):
    row["keywords"]=[x.lower() for x in row["keywords"]]
    global count_non_empty
    count_non_empty = count_non_empty + 1
    non_generated_keywords.extend(row["keywords"])
    # print( row["title"] )
    # print( str( row["keywords"] ) + "\n\n" )
  non_generated_keywords = sorted(non_generated_keywords, key=len, reverse=True) # sorting by length
  non_generated_keywords = list(dict.fromkeys(non_generated_keywords)) # removing duplicate keywords



def generate_keywords(row):
  if ( row["keywords"] == [] ):
    global count_empty
    global non_generated_keywords
    count_empty = count_empty + 1
    # print( row["title"] )
    keywords=[]
    generated_keywords = get_keywords( row["title"] )
    for i in range(0, len( non_generated_keywords ) ):
      if ( non_generated_keywords[i] in generated_keywords ):
        generated_keywords = generated_keywords.replace( non_generated_keywords[i], "" )
        keywords.append( non_generated_keywords[i] )
    keywords.extend( generated_keywords.split( ' ' ) )
    keywords=[x.lower() for x in keywords]
    valid_characters = set('abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ\\- /_0123456789')
    # as such: "!"#$%&'()*+,.:;<=>?@[\\]^`{|}~" are now allowed of keyword names
    for keyword in keywords:
      keyword = ''.join(c for c in keyword if c in valid_characters)

    for keyword in keywords:
      for i in range(0, len(keyword)):
        if keyword[i] in "abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789":
          break
        if keyword[i] in "\\- /_":
          if ( keyword in keywords ):
            keywords.remove(keyword)
          keywords.append(keyword[1:])
      for i in range(len(keyword)-1, -1, -1):
        if keyword[i] in "abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789":
          break
        if keyword[i] in "\\- /_":
          if ( keyword in keywords ):
            keywords.remove(keyword)
          keywords.append(keyword[1:])

    while '' in keywords:
        keywords.remove('')

    return str( keywords )
  else:
    return str( row["keywords"] )

non_generated_keywords_file = Path("/content/drive/MyDrive/non_generated_keywords.csv")
if non_generated_keywords_file.is_file():
  non_generated_keywords = list(pd.read_csv(str(non_generated_keywords_file.resolve()))["keyword"])
  print( "Non-generated keywords retrieved from \"non_generated_keywords.csv\"!" )
else:
  df.apply(determine_keywords, axis=1)
  non_generated_keywords_df = pd.DataFrame( non_generated_keywords, columns=["keyword"] )
  non_generated_keywords_df.to_csv("/content/drive/MyDrive/non_generated_keywords.csv", encoding='utf-8', index=False)
  print( "Non-generated keywords were re-generated and saved to \"non_generated_keywords.csv\"!" )

df["keywords"]=df.apply(generate_keywords, axis=1)
print( "Papers with NO keywords: " + str(count_empty) + "/" + str(df.shape[0]) ) # most were empty
print( "Papers with keywords: " + str(count_non_empty) + "/" + str(df.shape[0]) )
# Out:
# Stop words retrieved from "stop_words.csv"!
# Non-generated keywords retrieved from "non_generated_keywords.csv"!
# Papers with NO keywords: 24312/26806
# Papers with keywords: 0/26806

# %%
df.to_csv("/content/drive/MyDrive/checkpoint_2_df.csv", encoding='utf-8', index=False)

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/checkpoint_2_df.csv")

# %%
# Getting the article language and institution (only way, for the language at least) ...

# GIVES "HTTP Error 429: Too Many Requests" FOR 26806 articles ...

import urllib.request
from bs4 import BeautifulSoup

def get_page(url):
  fp = urllib.request.urlopen(url)
  mybytes = fp.read()
  html_page = mybytes.decode("utf8")
  fp.close()
  soup = BeautifulSoup(html_page)
  return soup

# def get_institution(row):
#   soup = get_page( row[ "url" ] )
#   # Here extracting paragraphs from the abstract ... yet maybe not all of them have paragraphs

#   # for i in soup.find("div", {"id": "abstract"}).find_all("strong", {"class": "sub-title"}):
#   #   p = i.parent
#   #   i.extract()
#   #   print( "\"" + str( p.text ).strip() + "\"" )
#   obj = soup.find("meta", {"name": "citation_author_institution"})
#   if ( obj != None ):
#     return obj['content']
#   return ""

# def get_language(row):
#   soup = get_page( row[ "url" ] )
#   return soup.find("meta", {"name": "citation_language"})['content']

# df['institution'] = df.apply(get_institution, axis=1)
# df['language'] = df.apply(get_language, axis=1)

# %%
# Getting all the journal data that is available though the issn number ...
import json

i = 0
row_num = len(df)
def get_issn_data ( row ):
  soup = get_page( "https://portal.issn.org/resource/ISSN/" + str(row["issn"]) )
  global i
  i = i + 1
  print( "Getting ISSN info "+str(i)+" / "+str(row_num) )

  container = soup.find(attrs={"id" : "tab0"})

  if ( container == None ):
    return "{}"

  info_container = container.find(attrs={"class" : "item-result-content-text"})
  spans = info_container.find_all('span')
  journal_data={}
  for span in spans:
    attr = span.text
    parent = span.parent
    span.extract()

    attr = attr.replace(":", "").strip().lower()
    value = parent.text.strip().lower()
    if attr not in journal_data:
      journal_data[ attr ]=value
    else:
      if ( type( journal_data[ attr ] ).__name__ == 'list' ):
        journal_data[ attr ].append( value )
      else:
        journal_data[ attr ]=[ journal_data[ attr ], value ]
  return json.dumps(journal_data)

df["issn_data"]=df.apply(get_issn_data, axis=1)
# Out:
# Streaming output truncated to the last 5000 lines.
# Getting ISSN info 21807 / 26806
# Getting ISSN info 21808 / 26806
# Getting ISSN info 21809 / 26806
# Getting ISSN info 21810 / 26806
# Getting ISSN info 21811 / 26806
# Getting ISSN info 21812 / 26806
# Getting ISSN info 21813 / 26806
# Getting ISSN info 21814 / 26806
# Getting ISSN info 21815 / 26806
# Getting ISSN info 21816 / 26806
# Getting ISSN info 21817 / 26806
# Getting ISSN info 21818 / 26806
# Getting ISSN info 21819 / 26806
# Getting ISSN info 21820 / 26806
# Getting ISSN info 21821 / 26806
# Getting ISSN info 21822 / 26806
# Getting ISSN info 21823 / 26806
# Getting ISSN info 21824 / 26806
# Getting ISSN info 21825 / 26806
# Getting ISSN info 21826 / 26806
# Getting ISSN info 21827 / 26806
# Getting ISSN info 21828 / 26806
# Getting ISSN info 21829 / 26806
# Getting ISSN info 21830 / 26806
# Getting ISSN info 21831 / 26806
# Getting ISSN info 21832 / 26806
# Getting ISSN info 21833 / 26806
# Getting ISSN info 21834 / 26806
# Getting ISSN info 21835 / 26806
# Getting ISSN info 21836 / 26806
# Getting ISSN info 21837 / 26806
# Getting ISSN info 21838 / 26806
# Getting ISSN info 21839 / 26806
# Getting ISSN info 21840 / 26806
# Getting ISSN info 21841 / 26806
# Getting ISSN info 21842 / 26806
# Getting ISSN info 21843 / 26806
# Getting ISSN info 21844 / 26806
# Getting ISSN info 21845 / 26806
# Getting ISSN info 21846 / 26806
# Getting ISSN info 21847 / 26806
# Getting ISSN info 21848 / 26806
# Getting ISSN info 21849 / 26806
# Getting ISSN info 21850 / 26806
# Getting ISSN info 21851 / 26806
# Getting ISSN info 21852 / 26806
# Getting ISSN info 21853 / 26806
# Getting ISSN info 21854 / 26806
# Getting ISSN info 21855 / 26806
# Getting ISSN info 21856 / 26806
# Getting ISSN info 21857 / 26806
# Getting ISSN info 21858 / 26806
# Getting ISSN info 21859 / 26806
# Getting ISSN info 21860 / 26806
# Getting ISSN info 21861 / 26806
# Getting ISSN info 21862 / 26806
# Getting ISSN info 21863 / 26806
# Getting ISSN info 21864 / 26806
# Getting ISSN info 21865 / 26806
# Getting ISSN info 21866 / 26806
# Getting ISSN info 21867 / 26806
# Getting ISSN info 21868 / 26806
# Getting ISSN info 21869 / 26806
# Getting ISSN info 21870 / 26806
# Getting ISSN info 21871 / 26806
# Getting ISSN info 21872 / 26806
# Getting ISSN info 21873 / 26806
# Getting ISSN info 21874 / 26806
# Getting ISSN info 21875 / 26806
# Getting ISSN info 21876 / 26806
# Getting ISSN info 21877 / 26806
# Getting ISSN info 21878 / 26806
# Getting ISSN info 21879 / 26806
# Getting ISSN info 21880 / 26806
# Getting ISSN info 21881 / 26806
# Getting ISSN info 21882 / 26806
# Getting ISSN info 21883 / 26806
# Getting ISSN info 21884 / 26806
# Getting ISSN info 21885 / 26806
# Getting ISSN info 21886 / 26806
# Getting ISSN info 21887 / 26806
# Getting ISSN info 21888 / 26806
# Getting ISSN info 21889 / 26806
# Getting ISSN info 21890 / 26806
# Getting ISSN info 21891 / 26806
# Getting ISSN info 21892 / 26806
# Getting ISSN info 21893 / 26806
# Getting ISSN info 21894 / 26806
# Getting ISSN info 21895 / 26806
# Getting ISSN info 21896 / 26806
# Getting ISSN info 21897 / 26806
# Getting ISSN info 21898 / 26806
# Getting ISSN info 21899 / 26806
# Getting ISSN info 21900 / 26806
# Getting ISSN info 21901 / 26806
# Getting ISSN info 21902 / 26806
# Getting ISSN info 21903 / 26806
# Getting ISSN info 21904 / 26806
# Getting ISSN info 21905 / 26806
# Getting ISSN info 21906 / 26806
# Getting ISSN info 21907 / 26806
# Getting ISSN info 21908 / 26806
# Getting ISSN info 21909 / 26806
# Getting ISSN info 21910 / 26806
# Getting ISSN info 21911 / 26806
# Getting ISSN info 21912 / 26806
# Getting ISSN info 21913 / 26806
# Getting ISSN info 21914 / 26806
# Getting ISSN info 21915 / 26806
# Getting ISSN info 21916 / 26806
# Getting ISSN info 21917 / 26806
# Getting ISSN info 21918 / 26806
# Getting ISSN info 21919 / 26806
# Getting ISSN info 21920 / 26806
# Getting ISSN info 21921 / 26806
# Getting ISSN info 21922 / 26806
# Getting ISSN info 21923 / 26806
# Getting ISSN info 21924 / 26806
# Getting ISSN info 21925 / 26806
# Getting ISSN info 21926 / 26806
# Getting ISSN info 21927 / 26806
# Getting ISSN info 21928 / 26806
# Getting ISSN info 21929 / 26806
# Getting ISSN info 21930 / 26806
# Getting ISSN info 21931 / 26806
# Getting ISSN info 21932 / 26806
# Getting ISSN info 21933 / 26806
# Getting ISSN info 21934 / 26806
# Getting ISSN info 21935 / 26806
# Getting ISSN info 21936 / 26806
# Getting ISSN info 21937 / 26806
# Getting ISSN info 21938 / 26806
# Getting ISSN info 21939 / 26806
# Getting ISSN info 21940 / 26806
# Getting ISSN info 21941 / 26806
# Getting ISSN info 21942 / 26806
# Getting ISSN info 21943 / 26806
# Getting ISSN info 21944 / 26806
# Getting ISSN info 21945 / 26806
# Getting ISSN info 21946 / 26806
# Getting ISSN info 21947 / 26806
# Getting ISSN info 21948 / 26806
# Getting ISSN info 21949 / 26806
# Getting ISSN info 21950 / 26806
# Getting ISSN info 21951 / 26806
# Getting ISSN info 21952 / 26806
# Getting ISSN info 21953 / 26806
# Getting ISSN info 21954 / 26806
# Getting ISSN info 21955 / 26806
# Getting ISSN info 21956 / 26806
# Getting ISSN info 21957 / 26806
# Getting ISSN info 21958 / 26806
# Getting ISSN info 21959 / 26806
# Getting ISSN info 21960 / 26806
# Getting ISSN info 21961 / 26806
# Getting ISSN info 21962 / 26806
# Getting ISSN info 21963 / 26806
# Getting ISSN info 21964 / 26806
# Getting ISSN info 21965 / 26806
# Getting ISSN info 21966 / 26806
# Getting ISSN info 21967 / 26806
# Getting ISSN info 21968 / 26806
# Getting ISSN info 21969 / 26806
# Getting ISSN info 21970 / 26806
# Getting ISSN info 21971 / 26806
# Getting ISSN info 21972 / 26806
# Getting ISSN info 21973 / 26806
# Getting ISSN info 21974 / 26806
# Getting ISSN info 21975 / 26806
# Getting ISSN info 21976 / 26806
# Getting ISSN info 21977 / 26806
# Getting ISSN info 21978 / 26806
# Getting ISSN info 21979 / 26806
# Getting ISSN info 21980 / 26806
# Getting ISSN info 21981 / 26806
# Getting ISSN info 21982 / 26806
# Getting ISSN info 21983 / 26806
# Getting ISSN info 21984 / 26806
# Getting ISSN info 21985 / 26806
# Getting ISSN info 21986 / 26806
# Getting ISSN info 21987 / 26806
# Getting ISSN info 21988 / 26806
# Getting ISSN info 21989 / 26806
# Getting ISSN info 21990 / 26806
# Getting ISSN info 21991 / 26806
# Getting ISSN info 21992 / 26806
# Getting ISSN info 21993 / 26806
# Getting ISSN info 21994 / 26806
# Getting ISSN info 21995 / 26806
# Getting ISSN info 21996 / 26806
# Getting ISSN info 21997 / 26806
# Getting ISSN info 21998 / 26806
# Getting ISSN info 21999 / 26806
# Getting ISSN info 22000 / 26806
# Getting ISSN info 22001 / 26806
# Getting ISSN info 22002 / 26806
# Getting ISSN info 22003 / 26806
# Getting ISSN info 22004 / 26806
# Getting ISSN info 22005 / 26806
# Getting ISSN info 22006 / 26806
# Getting ISSN info 22007 / 26806
# Getting ISSN info 22008 / 26806
# Getting ISSN info 22009 / 26806
# Getting ISSN info 22010 / 26806
# Getting ISSN info 22011 / 26806
# Getting ISSN info 22012 / 26806
# Getting ISSN info 22013 / 26806
# Getting ISSN info 22014 / 26806
# Getting ISSN info 22015 / 26806
# Getting ISSN info 22016 / 26806
# Getting ISSN info 22017 / 26806
# Getting ISSN info 22018 / 26806
# Getting ISSN info 22019 / 26806
# Getting ISSN info 22020 / 26806
# Getting ISSN info 22021 / 26806
# Getting ISSN info 22022 / 26806
# Getting ISSN info 22023 / 26806
# Getting ISSN info 22024 / 26806
# Getting ISSN info 22025 / 26806
# Getting ISSN info 22026 / 26806
# Getting ISSN info 22027 / 26806
# Getting ISSN info 22028 / 26806
# Getting ISSN info 22029 / 26806
# Getting ISSN info 22030 / 26806
# Getting ISSN info 22031 / 26806
# Getting ISSN info 22032 / 26806
# Getting ISSN info 22033 / 26806
# Getting ISSN info 22034 / 26806
# Getting ISSN info 22035 / 26806
# Getting ISSN info 22036 / 26806
# Getting ISSN info 22037 / 26806
# Getting ISSN info 22038 / 26806
# Getting ISSN info 22039 / 26806
# Getting ISSN info 22040 / 26806
# Getting ISSN info 22041 / 26806
# Getting ISSN info 22042 / 26806
# Getting ISSN info 22043 / 26806
# Getting ISSN info 22044 / 26806
# Getting ISSN info 22045 / 26806
# Getting ISSN info 22046 / 26806
# Getting ISSN info 22047 / 26806
# Getting ISSN info 22048 / 26806
# Getting ISSN info 22049 / 26806
# Getting ISSN info 22050 / 26806
# Getting ISSN info 22051 / 26806
# Getting ISSN info 22052 / 26806
# Getting ISSN info 22053 / 26806
# Getting ISSN info 22054 / 26806
# Getting ISSN info 22055 / 26806
# Getting ISSN info 22056 / 26806
# Getting ISSN info 22057 / 26806
# Getting ISSN info 22058 / 26806
# Getting ISSN info 22059 / 26806
# Getting ISSN info 22060 / 26806
# Getting ISSN info 22061 / 26806
# Getting ISSN info 22062 / 26806
# Getting ISSN info 22063 / 26806
# Getting ISSN info 22064 / 26806
# Getting ISSN info 22065 / 26806
# Getting ISSN info 22066 / 26806
# Getting ISSN info 22067 / 26806
# Getting ISSN info 22068 / 26806
# Getting ISSN info 22069 / 26806
# Getting ISSN info 22070 / 26806
# Getting ISSN info 22071 / 26806
# Getting ISSN info 22072 / 26806
# Getting ISSN info 22073 / 26806
# Getting ISSN info 22074 / 26806
# Getting ISSN info 22075 / 26806
# Getting ISSN info 22076 / 26806
# Getting ISSN info 22077 / 26806
# Getting ISSN info 22078 / 26806
# Getting ISSN info 22079 / 26806
# Getting ISSN info 22080 / 26806
# Getting ISSN info 22081 / 26806
# Getting ISSN info 22082 / 26806
# Getting ISSN info 22083 / 26806
# Getting ISSN info 22084 / 26806
# Getting ISSN info 22085 / 26806
# Getting ISSN info 22086 / 26806
# Getting ISSN info 22087 / 26806
# Getting ISSN info 22088 / 26806
# Getting ISSN info 22089 / 26806
# Getting ISSN info 22090 / 26806
# Getting ISSN info 22091 / 26806
# Getting ISSN info 22092 / 26806
# Getting ISSN info 22093 / 26806
# Getting ISSN info 22094 / 26806
# Getting ISSN info 22095 / 26806
# Getting ISSN info 22096 / 26806
# Getting ISSN info 22097 / 26806
# Getting ISSN info 22098 / 26806
# Getting ISSN info 22099 / 26806
# Getting ISSN info 22100 / 26806
# Getting ISSN info 22101 / 26806
# Getting ISSN info 22102 / 26806
# Getting ISSN info 22103 / 26806
# Getting ISSN info 22104 / 26806
# Getting ISSN info 22105 / 26806
# Getting ISSN info 22106 / 26806
# Getting ISSN info 22107 / 26806
# Getting ISSN info 22108 / 26806
# Getting ISSN info 22109 / 26806
# Getting ISSN info 22110 / 26806
# Getting ISSN info 22111 / 26806
# Getting ISSN info 22112 / 26806
# Getting ISSN info 22113 / 26806
# Getting ISSN info 22114 / 26806
# Getting ISSN info 22115 / 26806
# Getting ISSN info 22116 / 26806
# Getting ISSN info 22117 / 26806
# Getting ISSN info 22118 / 26806
# Getting ISSN info 22119 / 26806
# Getting ISSN info 22120 / 26806
# Getting ISSN info 22121 / 26806
# Getting ISSN info 22122 / 26806
# Getting ISSN info 22123 / 26806
# Getting ISSN info 22124 / 26806
# Getting ISSN info 22125 / 26806
# Getting ISSN info 22126 / 26806
# Getting ISSN info 22127 / 26806
# Getting ISSN info 22128 / 26806
# Getting ISSN info 22129 / 26806
# Getting ISSN info 22130 / 26806
# Getting ISSN info 22131 / 26806
# Getting ISSN info 22132 / 26806
# Getting ISSN info 22133 / 26806
# Getting ISSN info 22134 / 26806
# Getting ISSN info 22135 / 26806
# Getting ISSN info 22136 / 26806
# Getting ISSN info 22137 / 26806
# Getting ISSN info 22138 / 26806
# Getting ISSN info 22139 / 26806
# Getting ISSN info 22140 / 26806
# Getting ISSN info 22141 / 26806
# Getting ISSN info 22142 / 26806
# Getting ISSN info 22143 / 26806
# Getting ISSN info 22144 / 26806
# Getting ISSN info 22145 / 26806
# Getting ISSN info 22146 / 26806
# Getting ISSN info 22147 / 26806
# Getting ISSN info 22148 / 26806
# Getting ISSN info 22149 / 26806
# Getting ISSN info 22150 / 26806
# Getting ISSN info 22151 / 26806
# Getting ISSN info 22152 / 26806
# Getting ISSN info 22153 / 26806
# Getting ISSN info 22154 / 26806
# Getting ISSN info 22155 / 26806
# Getting ISSN info 22156 / 26806
# Getting ISSN info 22157 / 26806
# Getting ISSN info 22158 / 26806
# Getting ISSN info 22159 / 26806
# Getting ISSN info 22160 / 26806
# Getting ISSN info 22161 / 26806
# Getting ISSN info 22162 / 26806
# Getting ISSN info 22163 / 26806
# Getting ISSN info 22164 / 26806
# Getting ISSN info 22165 / 26806
# Getting ISSN info 22166 / 26806
# Getting ISSN info 22167 / 26806
# Getting ISSN info 22168 / 26806
# Getting ISSN info 22169 / 26806
# Getting ISSN info 22170 / 26806
# Getting ISSN info 22171 / 26806
# Getting ISSN info 22172 / 26806
# Getting ISSN info 22173 / 26806
# Getting ISSN info 22174 / 26806
# Getting ISSN info 22175 / 26806
# Getting ISSN info 22176 / 26806
# Getting ISSN info 22177 / 26806
# Getting ISSN info 22178 / 26806
# Getting ISSN info 22179 / 26806
# Getting ISSN info 22180 / 26806
# Getting ISSN info 22181 / 26806
# Getting ISSN info 22182 / 26806
# Getting ISSN info 22183 / 26806
# Getting ISSN info 22184 / 26806
# Getting ISSN info 22185 / 26806
# Getting ISSN info 22186 / 26806
# Getting ISSN info 22187 / 26806
# Getting ISSN info 22188 / 26806
# Getting ISSN info 22189 / 26806
# Getting ISSN info 22190 / 26806
# Getting ISSN info 22191 / 26806
# Getting ISSN info 22192 / 26806
# Getting ISSN info 22193 / 26806
# Getting ISSN info 22194 / 26806
# Getting ISSN info 22195 / 26806
# Getting ISSN info 22196 / 26806
# Getting ISSN info 22197 / 26806
# Getting ISSN info 22198 / 26806
# Getting ISSN info 22199 / 26806
# Getting ISSN info 22200 / 26806
# Getting ISSN info 22201 / 26806
# Getting ISSN info 22202 / 26806
# Getting ISSN info 22203 / 26806
# Getting ISSN info 22204 / 26806
# Getting ISSN info 22205 / 26806
# Getting ISSN info 22206 / 26806
# Getting ISSN info 22207 / 26806
# Getting ISSN info 22208 / 26806
# Getting ISSN info 22209 / 26806
# Getting ISSN info 22210 / 26806
# Getting ISSN info 22211 / 26806
# Getting ISSN info 22212 / 26806
# Getting ISSN info 22213 / 26806
# Getting ISSN info 22214 / 26806
# Getting ISSN info 22215 / 26806
# Getting ISSN info 22216 / 26806
# Getting ISSN info 22217 / 26806
# Getting ISSN info 22218 / 26806
# Getting ISSN info 22219 / 26806
# Getting ISSN info 22220 / 26806
# Getting ISSN info 22221 / 26806
# Getting ISSN info 22222 / 26806
# Getting ISSN info 22223 / 26806
# Getting ISSN info 22224 / 26806
# Getting ISSN info 22225 / 26806
# Getting ISSN info 22226 / 26806
# Getting ISSN info 22227 / 26806
# Getting ISSN info 22228 / 26806
# Getting ISSN info 22229 / 26806
# Getting ISSN info 22230 / 26806
# Getting ISSN info 22231 / 26806
# Getting ISSN info 22232 / 26806
# Getting ISSN info 22233 / 26806
# Getting ISSN info 22234 / 26806
# Getting ISSN info 22235 / 26806
# Getting ISSN info 22236 / 26806
# Getting ISSN info 22237 / 26806
# Getting ISSN info 22238 / 26806
# Getting ISSN info 22239 / 26806
# Getting ISSN info 22240 / 26806
# Getting ISSN info 22241 / 26806
# Getting ISSN info 22242 / 26806
# Getting ISSN info 22243 / 26806
# Getting ISSN info 22244 / 26806
# Getting ISSN info 22245 / 26806
# Getting ISSN info 22246 / 26806
# Getting ISSN info 22247 / 26806
# Getting ISSN info 22248 / 26806
# Getting ISSN info 22249 / 26806
# Getting ISSN info 22250 / 26806
# Getting ISSN info 22251 / 26806
# Getting ISSN info 22252 / 26806
# Getting ISSN info 22253 / 26806
# Getting ISSN info 22254 / 26806
# Getting ISSN info 22255 / 26806
# Getting ISSN info 22256 / 26806
# Getting ISSN info 22257 / 26806
# Getting ISSN info 22258 / 26806
# Getting ISSN info 22259 / 26806
# Getting ISSN info 22260 / 26806
# Getting ISSN info 22261 / 26806
# Getting ISSN info 22262 / 26806
# Getting ISSN info 22263 / 26806
# Getting ISSN info 22264 / 26806
# Getting ISSN info 22265 / 26806
# Getting ISSN info 22266 / 26806
# Getting ISSN info 22267 / 26806
# Getting ISSN info 22268 / 26806
# Getting ISSN info 22269 / 26806
# Getting ISSN info 22270 / 26806
# Getting ISSN info 22271 / 26806
# Getting ISSN info 22272 / 26806
# Getting ISSN info 22273 / 26806
# Getting ISSN info 22274 / 26806
# Getting ISSN info 22275 / 26806
# Getting ISSN info 22276 / 26806
# Getting ISSN info 22277 / 26806
# Getting ISSN info 22278 / 26806
# Getting ISSN info 22279 / 26806
# Getting ISSN info 22280 / 26806
# Getting ISSN info 22281 / 26806
# Getting ISSN info 22282 / 26806
# Getting ISSN info 22283 / 26806
# Getting ISSN info 22284 / 26806
# Getting ISSN info 22285 / 26806
# Getting ISSN info 22286 / 26806
# Getting ISSN info 22287 / 26806
# Getting ISSN info 22288 / 26806
# Getting ISSN info 22289 / 26806
# Getting ISSN info 22290 / 26806
# Getting ISSN info 22291 / 26806
# Getting ISSN info 22292 / 26806
# Getting ISSN info 22293 / 26806
# Getting ISSN info 22294 / 26806
# Getting ISSN info 22295 / 26806
# Getting ISSN info 22296 / 26806
# Getting ISSN info 22297 / 26806
# Getting ISSN info 22298 / 26806
# Getting ISSN info 22299 / 26806
# Getting ISSN info 22300 / 26806
# Getting ISSN info 22301 / 26806
# Getting ISSN info 22302 / 26806
# Getting ISSN info 22303 / 26806
# Getting ISSN info 22304 / 26806
# Getting ISSN info 22305 / 26806
# Getting ISSN info 22306 / 26806
# Getting ISSN info 22307 / 26806
# Getting ISSN info 22308 / 26806
# Getting ISSN info 22309 / 26806
# Getting ISSN info 22310 / 26806
# Getting ISSN info 22311 / 26806
# Getting ISSN info 22312 / 26806
# Getting ISSN info 22313 / 26806
# Getting ISSN info 22314 / 26806
# Getting ISSN info 22315 / 26806
# Getting ISSN info 22316 / 26806
# Getting ISSN info 22317 / 26806
# Getting ISSN info 22318 / 26806
# Getting ISSN info 22319 / 26806
# Getting ISSN info 22320 / 26806
# Getting ISSN info 22321 / 26806
# Getting ISSN info 22322 / 26806
# Getting ISSN info 22323 / 26806
# Getting ISSN info 22324 / 26806
# Getting ISSN info 22325 / 26806
# Getting ISSN info 22326 / 26806
# Getting ISSN info 22327 / 26806
# Getting ISSN info 22328 / 26806
# Getting ISSN info 22329 / 26806
# Getting ISSN info 22330 / 26806
# Getting ISSN info 22331 / 26806
# Getting ISSN info 22332 / 26806
# Getting ISSN info 22333 / 26806
# Getting ISSN info 22334 / 26806
# Getting ISSN info 22335 / 26806
# Getting ISSN info 22336 / 26806
# Getting ISSN info 22337 / 26806
# Getting ISSN info 22338 / 26806
# Getting ISSN info 22339 / 26806
# Getting ISSN info 22340 / 26806
# Getting ISSN info 22341 / 26806
# Getting ISSN info 22342 / 26806
# Getting ISSN info 22343 / 26806
# Getting ISSN info 22344 / 26806
# Getting ISSN info 22345 / 26806
# Getting ISSN info 22346 / 26806
# Getting ISSN info 22347 / 26806
# Getting ISSN info 22348 / 26806
# Getting ISSN info 22349 / 26806
# Getting ISSN info 22350 / 26806
# Getting ISSN info 22351 / 26806
# Getting ISSN info 22352 / 26806
# Getting ISSN info 22353 / 26806
# Getting ISSN info 22354 / 26806
# Getting ISSN info 22355 / 26806
# Getting ISSN info 22356 / 26806
# Getting ISSN info 22357 / 26806
# Getting ISSN info 22358 / 26806
# Getting ISSN info 22359 / 26806
# Getting ISSN info 22360 / 26806
# Getting ISSN info 22361 / 26806
# Getting ISSN info 22362 / 26806
# Getting ISSN info 22363 / 26806
# Getting ISSN info 22364 / 26806
# Getting ISSN info 22365 / 26806
# Getting ISSN info 22366 / 26806
# Getting ISSN info 22367 / 26806
# Getting ISSN info 22368 / 26806
# Getting ISSN info 22369 / 26806
# Getting ISSN info 22370 / 26806
# Getting ISSN info 22371 / 26806
# Getting ISSN info 22372 / 26806
# Getting ISSN info 22373 / 26806
# Getting ISSN info 22374 / 26806
# Getting ISSN info 22375 / 26806
# Getting ISSN info 22376 / 26806
# Getting ISSN info 22377 / 26806
# Getting ISSN info 22378 / 26806
# Getting ISSN info 22379 / 26806
# Getting ISSN info 22380 / 26806
# Getting ISSN info 22381 / 26806
# Getting ISSN info 22382 / 26806
# Getting ISSN info 22383 / 26806
# Getting ISSN info 22384 / 26806
# Getting ISSN info 22385 / 26806
# Getting ISSN info 22386 / 26806
# Getting ISSN info 22387 / 26806
# Getting ISSN info 22388 / 26806
# Getting ISSN info 22389 / 26806
# Getting ISSN info 22390 / 26806
# Getting ISSN info 22391 / 26806
# Getting ISSN info 22392 / 26806
# Getting ISSN info 22393 / 26806
# Getting ISSN info 22394 / 26806
# Getting ISSN info 22395 / 26806
# Getting ISSN info 22396 / 26806
# Getting ISSN info 22397 / 26806
# Getting ISSN info 22398 / 26806
# Getting ISSN info 22399 / 26806
# Getting ISSN info 22400 / 26806
# Getting ISSN info 22401 / 26806
# Getting ISSN info 22402 / 26806
# Getting ISSN info 22403 / 26806
# Getting ISSN info 22404 / 26806
# Getting ISSN info 22405 / 26806
# Getting ISSN info 22406 / 26806
# Getting ISSN info 22407 / 26806
# Getting ISSN info 22408 / 26806
# Getting ISSN info 22409 / 26806
# Getting ISSN info 22410 / 26806
# Getting ISSN info 22411 / 26806
# Getting ISSN info 22412 / 26806
# Getting ISSN info 22413 / 26806
# Getting ISSN info 22414 / 26806
# Getting ISSN info 22415 / 26806
# Getting ISSN info 22416 / 26806
# Getting ISSN info 22417 / 26806
# Getting ISSN info 22418 / 26806
# Getting ISSN info 22419 / 26806
# Getting ISSN info 22420 / 26806
# Getting ISSN info 22421 / 26806
# Getting ISSN info 22422 / 26806
# Getting ISSN info 22423 / 26806
# Getting ISSN info 22424 / 26806
# Getting ISSN info 22425 / 26806
# Getting ISSN info 22426 / 26806
# Getting ISSN info 22427 / 26806
# Getting ISSN info 22428 / 26806
# Getting ISSN info 22429 / 26806
# Getting ISSN info 22430 / 26806
# Getting ISSN info 22431 / 26806
# Getting ISSN info 22432 / 26806
# Getting ISSN info 22433 / 26806
# Getting ISSN info 22434 / 26806
# Getting ISSN info 22435 / 26806
# Getting ISSN info 22436 / 26806
# Getting ISSN info 22437 / 26806
# Getting ISSN info 22438 / 26806
# Getting ISSN info 22439 / 26806
# Getting ISSN info 22440 / 26806
# Getting ISSN info 22441 / 26806
# Getting ISSN info 22442 / 26806
# Getting ISSN info 22443 / 26806
# Getting ISSN info 22444 / 26806
# Getting ISSN info 22445 / 26806
# Getting ISSN info 22446 / 26806
# Getting ISSN info 22447 / 26806
# Getting ISSN info 22448 / 26806
# Getting ISSN info 22449 / 26806
# Getting ISSN info 22450 / 26806
# Getting ISSN info 22451 / 26806
# Getting ISSN info 22452 / 26806
# Getting ISSN info 22453 / 26806
# Getting ISSN info 22454 / 26806
# Getting ISSN info 22455 / 26806
# Getting ISSN info 22456 / 26806
# Getting ISSN info 22457 / 26806
# Getting ISSN info 22458 / 26806
# Getting ISSN info 22459 / 26806
# Getting ISSN info 22460 / 26806
# Getting ISSN info 22461 / 26806
# Getting ISSN info 22462 / 26806
# Getting ISSN info 22463 / 26806
# Getting ISSN info 22464 / 26806
# Getting ISSN info 22465 / 26806
# Getting ISSN info 22466 / 26806
# Getting ISSN info 22467 / 26806
# Getting ISSN info 22468 / 26806
# Getting ISSN info 22469 / 26806
# Getting ISSN info 22470 / 26806
# Getting ISSN info 22471 / 26806
# Getting ISSN info 22472 / 26806
# Getting ISSN info 22473 / 26806
# Getting ISSN info 22474 / 26806
# Getting ISSN info 22475 / 26806
# Getting ISSN info 22476 / 26806
# Getting ISSN info 22477 / 26806
# Getting ISSN info 22478 / 26806
# Getting ISSN info 22479 / 26806
# Getting ISSN info 22480 / 26806
# Getting ISSN info 22481 / 26806
# Getting ISSN info 22482 / 26806
# Getting ISSN info 22483 / 26806
# Getting ISSN info 22484 / 26806
# Getting ISSN info 22485 / 26806
# Getting ISSN info 22486 / 26806
# Getting ISSN info 22487 / 26806
# Getting ISSN info 22488 / 26806
# Getting ISSN info 22489 / 26806
# Getting ISSN info 22490 / 26806
# Getting ISSN info 22491 / 26806
# Getting ISSN info 22492 / 26806
# Getting ISSN info 22493 / 26806
# Getting ISSN info 22494 / 26806
# Getting ISSN info 22495 / 26806
# Getting ISSN info 22496 / 26806
# Getting ISSN info 22497 / 26806
# Getting ISSN info 22498 / 26806
# Getting ISSN info 22499 / 26806
# Getting ISSN info 22500 / 26806
# Getting ISSN info 22501 / 26806
# Getting ISSN info 22502 / 26806
# Getting ISSN info 22503 / 26806
# Getting ISSN info 22504 / 26806
# Getting ISSN info 22505 / 26806
# Getting ISSN info 22506 / 26806
# Getting ISSN info 22507 / 26806
# Getting ISSN info 22508 / 26806
# Getting ISSN info 22509 / 26806
# Getting ISSN info 22510 / 26806
# Getting ISSN info 22511 / 26806
# Getting ISSN info 22512 / 26806
# Getting ISSN info 22513 / 26806
# Getting ISSN info 22514 / 26806
# Getting ISSN info 22515 / 26806
# Getting ISSN info 22516 / 26806
# Getting ISSN info 22517 / 26806
# Getting ISSN info 22518 / 26806
# Getting ISSN info 22519 / 26806
# Getting ISSN info 22520 / 26806
# Getting ISSN info 22521 / 26806
# Getting ISSN info 22522 / 26806
# Getting ISSN info 22523 / 26806
# Getting ISSN info 22524 / 26806
# Getting ISSN info 22525 / 26806
# Getting ISSN info 22526 / 26806
# Getting ISSN info 22527 / 26806
# Getting ISSN info 22528 / 26806
# Getting ISSN info 22529 / 26806
# Getting ISSN info 22530 / 26806
# Getting ISSN info 22531 / 26806
# Getting ISSN info 22532 / 26806
# Getting ISSN info 22533 / 26806
# Getting ISSN info 22534 / 26806
# Getting ISSN info 22535 / 26806
# Getting ISSN info 22536 / 26806
# Getting ISSN info 22537 / 26806
# Getting ISSN info 22538 / 26806
# Getting ISSN info 22539 / 26806
# Getting ISSN info 22540 / 26806
# Getting ISSN info 22541 / 26806
# Getting ISSN info 22542 / 26806
# Getting ISSN info 22543 / 26806
# Getting ISSN info 22544 / 26806
# Getting ISSN info 22545 / 26806
# Getting ISSN info 22546 / 26806
# Getting ISSN info 22547 / 26806
# Getting ISSN info 22548 / 26806
# Getting ISSN info 22549 / 26806
# Getting ISSN info 22550 / 26806
# Getting ISSN info 22551 / 26806
# Getting ISSN info 22552 / 26806
# Getting ISSN info 22553 / 26806
# Getting ISSN info 22554 / 26806
# Getting ISSN info 22555 / 26806
# Getting ISSN info 22556 / 26806
# Getting ISSN info 22557 / 26806
# Getting ISSN info 22558 / 26806
# Getting ISSN info 22559 / 26806
# Getting ISSN info 22560 / 26806
# Getting ISSN info 22561 / 26806
# Getting ISSN info 22562 / 26806
# Getting ISSN info 22563 / 26806
# Getting ISSN info 22564 / 26806
# Getting ISSN info 22565 / 26806
# Getting ISSN info 22566 / 26806
# Getting ISSN info 22567 / 26806
# Getting ISSN info 22568 / 26806
# Getting ISSN info 22569 / 26806
# Getting ISSN info 22570 / 26806
# Getting ISSN info 22571 / 26806
# Getting ISSN info 22572 / 26806
# Getting ISSN info 22573 / 26806
# Getting ISSN info 22574 / 26806
# Getting ISSN info 22575 / 26806
# Getting ISSN info 22576 / 26806
# Getting ISSN info 22577 / 26806
# Getting ISSN info 22578 / 26806
# Getting ISSN info 22579 / 26806
# Getting ISSN info 22580 / 26806
# Getting ISSN info 22581 / 26806
# Getting ISSN info 22582 / 26806
# Getting ISSN info 22583 / 26806
# Getting ISSN info 22584 / 26806
# Getting ISSN info 22585 / 26806
# Getting ISSN info 22586 / 26806
# Getting ISSN info 22587 / 26806
# Getting ISSN info 22588 / 26806
# Getting ISSN info 22589 / 26806
# Getting ISSN info 22590 / 26806
# Getting ISSN info 22591 / 26806
# Getting ISSN info 22592 / 26806
# Getting ISSN info 22593 / 26806
# Getting ISSN info 22594 / 26806
# Getting ISSN info 22595 / 26806
# Getting ISSN info 22596 / 26806
# Getting ISSN info 22597 / 26806
# Getting ISSN info 22598 / 26806
# Getting ISSN info 22599 / 26806
# Getting ISSN info 22600 / 26806
# Getting ISSN info 22601 / 26806
# Getting ISSN info 22602 / 26806
# Getting ISSN info 22603 / 26806
# Getting ISSN info 22604 / 26806
# Getting ISSN info 22605 / 26806
# Getting ISSN info 22606 / 26806
# Getting ISSN info 22607 / 26806
# Getting ISSN info 22608 / 26806
# Getting ISSN info 22609 / 26806
# Getting ISSN info 22610 / 26806
# Getting ISSN info 22611 / 26806
# Getting ISSN info 22612 / 26806
# Getting ISSN info 22613 / 26806
# Getting ISSN info 22614 / 26806
# Getting ISSN info 22615 / 26806
# Getting ISSN info 22616 / 26806
# Getting ISSN info 22617 / 26806
# Getting ISSN info 22618 / 26806
# Getting ISSN info 22619 / 26806
# Getting ISSN info 22620 / 26806
# Getting ISSN info 22621 / 26806
# Getting ISSN info 22622 / 26806
# Getting ISSN info 22623 / 26806
# Getting ISSN info 22624 / 26806
# Getting ISSN info 22625 / 26806
# Getting ISSN info 22626 / 26806
# Getting ISSN info 22627 / 26806
# Getting ISSN info 22628 / 26806
# Getting ISSN info 22629 / 26806
# Getting ISSN info 22630 / 26806
# Getting ISSN info 22631 / 26806
# Getting ISSN info 22632 / 26806
# Getting ISSN info 22633 / 26806
# Getting ISSN info 22634 / 26806
# Getting ISSN info 22635 / 26806
# Getting ISSN info 22636 / 26806
# Getting ISSN info 22637 / 26806
# Getting ISSN info 22638 / 26806
# Getting ISSN info 22639 / 26806
# Getting ISSN info 22640 / 26806
# Getting ISSN info 22641 / 26806
# Getting ISSN info 22642 / 26806
# Getting ISSN info 22643 / 26806
# Getting ISSN info 22644 / 26806
# Getting ISSN info 22645 / 26806
# Getting ISSN info 22646 / 26806
# Getting ISSN info 22647 / 26806
# Getting ISSN info 22648 / 26806
# Getting ISSN info 22649 / 26806
# Getting ISSN info 22650 / 26806
# Getting ISSN info 22651 / 26806
# Getting ISSN info 22652 / 26806
# Getting ISSN info 22653 / 26806
# Getting ISSN info 22654 / 26806
# Getting ISSN info 22655 / 26806
# Getting ISSN info 22656 / 26806
# Getting ISSN info 22657 / 26806
# Getting ISSN info 22658 / 26806
# Getting ISSN info 22659 / 26806
# Getting ISSN info 22660 / 26806
# Getting ISSN info 22661 / 26806
# Getting ISSN info 22662 / 26806
# Getting ISSN info 22663 / 26806
# Getting ISSN info 22664 / 26806
# Getting ISSN info 22665 / 26806
# Getting ISSN info 22666 / 26806
# Getting ISSN info 22667 / 26806
# Getting ISSN info 22668 / 26806
# Getting ISSN info 22669 / 26806
# Getting ISSN info 22670 / 26806
# Getting ISSN info 22671 / 26806
# Getting ISSN info 22672 / 26806
# Getting ISSN info 22673 / 26806
# Getting ISSN info 22674 / 26806
# Getting ISSN info 22675 / 26806
# Getting ISSN info 22676 / 26806
# Getting ISSN info 22677 / 26806
# Getting ISSN info 22678 / 26806
# Getting ISSN info 22679 / 26806
# Getting ISSN info 22680 / 26806
# Getting ISSN info 22681 / 26806
# Getting ISSN info 22682 / 26806
# Getting ISSN info 22683 / 26806
# Getting ISSN info 22684 / 26806
# Getting ISSN info 22685 / 26806
# Getting ISSN info 22686 / 26806
# Getting ISSN info 22687 / 26806
# Getting ISSN info 22688 / 26806
# Getting ISSN info 22689 / 26806
# Getting ISSN info 22690 / 26806
# Getting ISSN info 22691 / 26806
# Getting ISSN info 22692 / 26806
# Getting ISSN info 22693 / 26806
# Getting ISSN info 22694 / 26806
# Getting ISSN info 22695 / 26806
# Getting ISSN info 22696 / 26806
# Getting ISSN info 22697 / 26806
# Getting ISSN info 22698 / 26806
# Getting ISSN info 22699 / 26806
# Getting ISSN info 22700 / 26806
# Getting ISSN info 22701 / 26806
# Getting ISSN info 22702 / 26806
# Getting ISSN info 22703 / 26806
# Getting ISSN info 22704 / 26806
# Getting ISSN info 22705 / 26806
# Getting ISSN info 22706 / 26806
# Getting ISSN info 22707 / 26806
# Getting ISSN info 22708 / 26806
# Getting ISSN info 22709 / 26806
# Getting ISSN info 22710 / 26806
# Getting ISSN info 22711 / 26806
# Getting ISSN info 22712 / 26806
# Getting ISSN info 22713 / 26806
# Getting ISSN info 22714 / 26806
# Getting ISSN info 22715 / 26806
# Getting ISSN info 22716 / 26806
# Getting ISSN info 22717 / 26806
# Getting ISSN info 22718 / 26806
# Getting ISSN info 22719 / 26806
# Getting ISSN info 22720 / 26806
# Getting ISSN info 22721 / 26806
# Getting ISSN info 22722 / 26806
# Getting ISSN info 22723 / 26806
# Getting ISSN info 22724 / 26806
# Getting ISSN info 22725 / 26806
# Getting ISSN info 22726 / 26806
# Getting ISSN info 22727 / 26806
# Getting ISSN info 22728 / 26806
# Getting ISSN info 22729 / 26806
# Getting ISSN info 22730 / 26806
# Getting ISSN info 22731 / 26806
# Getting ISSN info 22732 / 26806
# Getting ISSN info 22733 / 26806
# Getting ISSN info 22734 / 26806
# Getting ISSN info 22735 / 26806
# Getting ISSN info 22736 / 26806
# Getting ISSN info 22737 / 26806
# Getting ISSN info 22738 / 26806
# Getting ISSN info 22739 / 26806
# Getting ISSN info 22740 / 26806
# Getting ISSN info 22741 / 26806
# Getting ISSN info 22742 / 26806
# Getting ISSN info 22743 / 26806
# Getting ISSN info 22744 / 26806
# Getting ISSN info 22745 / 26806
# Getting ISSN info 22746 / 26806
# Getting ISSN info 22747 / 26806
# Getting ISSN info 22748 / 26806
# Getting ISSN info 22749 / 26806
# Getting ISSN info 22750 / 26806
# Getting ISSN info 22751 / 26806
# Getting ISSN info 22752 / 26806
# Getting ISSN info 22753 / 26806
# Getting ISSN info 22754 / 26806
# Getting ISSN info 22755 / 26806
# Getting ISSN info 22756 / 26806
# Getting ISSN info 22757 / 26806
# Getting ISSN info 22758 / 26806
# Getting ISSN info 22759 / 26806
# Getting ISSN info 22760 / 26806
# Getting ISSN info 22761 / 26806
# Getting ISSN info 22762 / 26806
# Getting ISSN info 22763 / 26806
# Getting ISSN info 22764 / 26806
# Getting ISSN info 22765 / 26806
# Getting ISSN info 22766 / 26806
# Getting ISSN info 22767 / 26806
# Getting ISSN info 22768 / 26806
# Getting ISSN info 22769 / 26806
# Getting ISSN info 22770 / 26806
# Getting ISSN info 22771 / 26806
# Getting ISSN info 22772 / 26806
# Getting ISSN info 22773 / 26806
# Getting ISSN info 22774 / 26806
# Getting ISSN info 22775 / 26806
# Getting ISSN info 22776 / 26806
# Getting ISSN info 22777 / 26806
# Getting ISSN info 22778 / 26806
# Getting ISSN info 22779 / 26806
# Getting ISSN info 22780 / 26806
# Getting ISSN info 22781 / 26806
# Getting ISSN info 22782 / 26806
# Getting ISSN info 22783 / 26806
# Getting ISSN info 22784 / 26806
# Getting ISSN info 22785 / 26806
# Getting ISSN info 22786 / 26806
# Getting ISSN info 22787 / 26806
# Getting ISSN info 22788 / 26806
# Getting ISSN info 22789 / 26806
# Getting ISSN info 22790 / 26806
# Getting ISSN info 22791 / 26806
# Getting ISSN info 22792 / 26806
# Getting ISSN info 22793 / 26806
# Getting ISSN info 22794 / 26806
# Getting ISSN info 22795 / 26806
# Getting ISSN info 22796 / 26806
# Getting ISSN info 22797 / 26806
# Getting ISSN info 22798 / 26806
# Getting ISSN info 22799 / 26806
# Getting ISSN info 22800 / 26806
# Getting ISSN info 22801 / 26806
# Getting ISSN info 22802 / 26806
# Getting ISSN info 22803 / 26806
# Getting ISSN info 22804 / 26806
# Getting ISSN info 22805 / 26806
# Getting ISSN info 22806 / 26806
# Getting ISSN info 22807 / 26806
# Getting ISSN info 22808 / 26806
# Getting ISSN info 22809 / 26806
# Getting ISSN info 22810 / 26806
# Getting ISSN info 22811 / 26806
# Getting ISSN info 22812 / 26806
# Getting ISSN info 22813 / 26806
# Getting ISSN info 22814 / 26806
# Getting ISSN info 22815 / 26806
# Getting ISSN info 22816 / 26806
# Getting ISSN info 22817 / 26806
# Getting ISSN info 22818 / 26806
# Getting ISSN info 22819 / 26806
# Getting ISSN info 22820 / 26806
# Getting ISSN info 22821 / 26806
# Getting ISSN info 22822 / 26806
# Getting ISSN info 22823 / 26806
# Getting ISSN info 22824 / 26806
# Getting ISSN info 22825 / 26806
# Getting ISSN info 22826 / 26806
# Getting ISSN info 22827 / 26806
# Getting ISSN info 22828 / 26806
# Getting ISSN info 22829 / 26806
# Getting ISSN info 22830 / 26806
# Getting ISSN info 22831 / 26806
# Getting ISSN info 22832 / 26806
# Getting ISSN info 22833 / 26806
# Getting ISSN info 22834 / 26806
# Getting ISSN info 22835 / 26806
# Getting ISSN info 22836 / 26806
# Getting ISSN info 22837 / 26806
# Getting ISSN info 22838 / 26806
# Getting ISSN info 22839 / 26806
# Getting ISSN info 22840 / 26806
# Getting ISSN info 22841 / 26806
# Getting ISSN info 22842 / 26806
# Getting ISSN info 22843 / 26806
# Getting ISSN info 22844 / 26806
# Getting ISSN info 22845 / 26806
# Getting ISSN info 22846 / 26806
# Getting ISSN info 22847 / 26806
# Getting ISSN info 22848 / 26806
# Getting ISSN info 22849 / 26806
# Getting ISSN info 22850 / 26806
# Getting ISSN info 22851 / 26806
# Getting ISSN info 22852 / 26806
# Getting ISSN info 22853 / 26806
# Getting ISSN info 22854 / 26806
# Getting ISSN info 22855 / 26806
# Getting ISSN info 22856 / 26806
# Getting ISSN info 22857 / 26806
# Getting ISSN info 22858 / 26806
# Getting ISSN info 22859 / 26806
# Getting ISSN info 22860 / 26806
# Getting ISSN info 22861 / 26806
# Getting ISSN info 22862 / 26806
# Getting ISSN info 22863 / 26806
# Getting ISSN info 22864 / 26806
# Getting ISSN info 22865 / 26806
# Getting ISSN info 22866 / 26806
# Getting ISSN info 22867 / 26806
# Getting ISSN info 22868 / 26806
# Getting ISSN info 22869 / 26806
# Getting ISSN info 22870 / 26806
# Getting ISSN info 22871 / 26806
# Getting ISSN info 22872 / 26806
# Getting ISSN info 22873 / 26806
# Getting ISSN info 22874 / 26806
# Getting ISSN info 22875 / 26806
# Getting ISSN info 22876 / 26806
# Getting ISSN info 22877 / 26806
# Getting ISSN info 22878 / 26806
# Getting ISSN info 22879 / 26806
# Getting ISSN info 22880 / 26806
# Getting ISSN info 22881 / 26806
# Getting ISSN info 22882 / 26806
# Getting ISSN info 22883 / 26806
# Getting ISSN info 22884 / 26806
# Getting ISSN info 22885 / 26806
# Getting ISSN info 22886 / 26806
# Getting ISSN info 22887 / 26806
# Getting ISSN info 22888 / 26806
# Getting ISSN info 22889 / 26806
# Getting ISSN info 22890 / 26806
# Getting ISSN info 22891 / 26806
# Getting ISSN info 22892 / 26806
# Getting ISSN info 22893 / 26806
# Getting ISSN info 22894 / 26806
# Getting ISSN info 22895 / 26806
# Getting ISSN info 22896 / 26806
# Getting ISSN info 22897 / 26806
# Getting ISSN info 22898 / 26806
# Getting ISSN info 22899 / 26806
# Getting ISSN info 22900 / 26806
# Getting ISSN info 22901 / 26806
# Getting ISSN info 22902 / 26806
# Getting ISSN info 22903 / 26806
# Getting ISSN info 22904 / 26806
# Getting ISSN info 22905 / 26806
# Getting ISSN info 22906 / 26806
# Getting ISSN info 22907 / 26806
# Getting ISSN info 22908 / 26806
# Getting ISSN info 22909 / 26806
# Getting ISSN info 22910 / 26806
# Getting ISSN info 22911 / 26806
# Getting ISSN info 22912 / 26806
# Getting ISSN info 22913 / 26806
# Getting ISSN info 22914 / 26806
# Getting ISSN info 22915 / 26806
# Getting ISSN info 22916 / 26806
# Getting ISSN info 22917 / 26806
# Getting ISSN info 22918 / 26806
# Getting ISSN info 22919 / 26806
# Getting ISSN info 22920 / 26806
# Getting ISSN info 22921 / 26806
# Getting ISSN info 22922 / 26806
# Getting ISSN info 22923 / 26806
# Getting ISSN info 22924 / 26806
# Getting ISSN info 22925 / 26806
# Getting ISSN info 22926 / 26806
# Getting ISSN info 22927 / 26806
# Getting ISSN info 22928 / 26806
# Getting ISSN info 22929 / 26806
# Getting ISSN info 22930 / 26806
# Getting ISSN info 22931 / 26806
# Getting ISSN info 22932 / 26806
# Getting ISSN info 22933 / 26806
# Getting ISSN info 22934 / 26806
# Getting ISSN info 22935 / 26806
# Getting ISSN info 22936 / 26806
# Getting ISSN info 22937 / 26806
# Getting ISSN info 22938 / 26806
# Getting ISSN info 22939 / 26806
# Getting ISSN info 22940 / 26806
# Getting ISSN info 22941 / 26806
# Getting ISSN info 22942 / 26806
# Getting ISSN info 22943 / 26806
# Getting ISSN info 22944 / 26806
# Getting ISSN info 22945 / 26806
# Getting ISSN info 22946 / 26806
# Getting ISSN info 22947 / 26806
# Getting ISSN info 22948 / 26806
# Getting ISSN info 22949 / 26806
# Getting ISSN info 22950 / 26806
# Getting ISSN info 22951 / 26806
# Getting ISSN info 22952 / 26806
# Getting ISSN info 22953 / 26806
# Getting ISSN info 22954 / 26806
# Getting ISSN info 22955 / 26806
# Getting ISSN info 22956 / 26806
# Getting ISSN info 22957 / 26806
# Getting ISSN info 22958 / 26806
# Getting ISSN info 22959 / 26806
# Getting ISSN info 22960 / 26806
# Getting ISSN info 22961 / 26806
# Getting ISSN info 22962 / 26806
# Getting ISSN info 22963 / 26806
# Getting ISSN info 22964 / 26806
# Getting ISSN info 22965 / 26806
# Getting ISSN info 22966 / 26806
# Getting ISSN info 22967 / 26806
# Getting ISSN info 22968 / 26806
# Getting ISSN info 22969 / 26806
# Getting ISSN info 22970 / 26806
# Getting ISSN info 22971 / 26806
# Getting ISSN info 22972 / 26806
# Getting ISSN info 22973 / 26806
# Getting ISSN info 22974 / 26806
# Getting ISSN info 22975 / 26806
# Getting ISSN info 22976 / 26806
# Getting ISSN info 22977 / 26806
# Getting ISSN info 22978 / 26806
# Getting ISSN info 22979 / 26806
# Getting ISSN info 22980 / 26806
# Getting ISSN info 22981 / 26806
# Getting ISSN info 22982 / 26806
# Getting ISSN info 22983 / 26806
# Getting ISSN info 22984 / 26806
# Getting ISSN info 22985 / 26806
# Getting ISSN info 22986 / 26806
# Getting ISSN info 22987 / 26806
# Getting ISSN info 22988 / 26806
# Getting ISSN info 22989 / 26806
# Getting ISSN info 22990 / 26806
# Getting ISSN info 22991 / 26806
# Getting ISSN info 22992 / 26806
# Getting ISSN info 22993 / 26806
# Getting ISSN info 22994 / 26806
# Getting ISSN info 22995 / 26806
# Getting ISSN info 22996 / 26806
# Getting ISSN info 22997 / 26806
# Getting ISSN info 22998 / 26806
# Getting ISSN info 22999 / 26806
# Getting ISSN info 23000 / 26806
# Getting ISSN info 23001 / 26806
# Getting ISSN info 23002 / 26806
# Getting ISSN info 23003 / 26806
# Getting ISSN info 23004 / 26806
# Getting ISSN info 23005 / 26806
# Getting ISSN info 23006 / 26806
# Getting ISSN info 23007 / 26806
# Getting ISSN info 23008 / 26806
# Getting ISSN info 23009 / 26806
# Getting ISSN info 23010 / 26806
# Getting ISSN info 23011 / 26806
# Getting ISSN info 23012 / 26806
# Getting ISSN info 23013 / 26806
# Getting ISSN info 23014 / 26806
# Getting ISSN info 23015 / 26806
# Getting ISSN info 23016 / 26806
# Getting ISSN info 23017 / 26806
# Getting ISSN info 23018 / 26806
# Getting ISSN info 23019 / 26806
# Getting ISSN info 23020 / 26806
# Getting ISSN info 23021 / 26806
# Getting ISSN info 23022 / 26806
# Getting ISSN info 23023 / 26806
# Getting ISSN info 23024 / 26806
# Getting ISSN info 23025 / 26806
# Getting ISSN info 23026 / 26806
# Getting ISSN info 23027 / 26806
# Getting ISSN info 23028 / 26806
# Getting ISSN info 23029 / 26806
# Getting ISSN info 23030 / 26806
# Getting ISSN info 23031 / 26806
# Getting ISSN info 23032 / 26806
# Getting ISSN info 23033 / 26806
# Getting ISSN info 23034 / 26806
# Getting ISSN info 23035 / 26806
# Getting ISSN info 23036 / 26806
# Getting ISSN info 23037 / 26806
# Getting ISSN info 23038 / 26806
# Getting ISSN info 23039 / 26806
# Getting ISSN info 23040 / 26806
# Getting ISSN info 23041 / 26806
# Getting ISSN info 23042 / 26806
# Getting ISSN info 23043 / 26806
# Getting ISSN info 23044 / 26806
# Getting ISSN info 23045 / 26806
# Getting ISSN info 23046 / 26806
# Getting ISSN info 23047 / 26806
# Getting ISSN info 23048 / 26806
# Getting ISSN info 23049 / 26806
# Getting ISSN info 23050 / 26806
# Getting ISSN info 23051 / 26806
# Getting ISSN info 23052 / 26806
# Getting ISSN info 23053 / 26806
# Getting ISSN info 23054 / 26806
# Getting ISSN info 23055 / 26806
# Getting ISSN info 23056 / 26806
# Getting ISSN info 23057 / 26806
# Getting ISSN info 23058 / 26806
# Getting ISSN info 23059 / 26806
# Getting ISSN info 23060 / 26806
# Getting ISSN info 23061 / 26806
# Getting ISSN info 23062 / 26806
# Getting ISSN info 23063 / 26806
# Getting ISSN info 23064 / 26806
# Getting ISSN info 23065 / 26806
# Getting ISSN info 23066 / 26806
# Getting ISSN info 23067 / 26806
# Getting ISSN info 23068 / 26806
# Getting ISSN info 23069 / 26806
# Getting ISSN info 23070 / 26806
# Getting ISSN info 23071 / 26806
# Getting ISSN info 23072 / 26806
# Getting ISSN info 23073 / 26806
# Getting ISSN info 23074 / 26806
# Getting ISSN info 23075 / 26806
# Getting ISSN info 23076 / 26806
# Getting ISSN info 23077 / 26806
# Getting ISSN info 23078 / 26806
# Getting ISSN info 23079 / 26806
# Getting ISSN info 23080 / 26806
# Getting ISSN info 23081 / 26806
# Getting ISSN info 23082 / 26806
# Getting ISSN info 23083 / 26806
# Getting ISSN info 23084 / 26806
# Getting ISSN info 23085 / 26806
# Getting ISSN info 23086 / 26806
# Getting ISSN info 23087 / 26806
# Getting ISSN info 23088 / 26806
# Getting ISSN info 23089 / 26806
# Getting ISSN info 23090 / 26806
# Getting ISSN info 23091 / 26806
# Getting ISSN info 23092 / 26806
# Getting ISSN info 23093 / 26806
# Getting ISSN info 23094 / 26806
# Getting ISSN info 23095 / 26806
# Getting ISSN info 23096 / 26806
# Getting ISSN info 23097 / 26806
# Getting ISSN info 23098 / 26806
# Getting ISSN info 23099 / 26806
# Getting ISSN info 23100 / 26806
# Getting ISSN info 23101 / 26806
# Getting ISSN info 23102 / 26806
# Getting ISSN info 23103 / 26806
# Getting ISSN info 23104 / 26806
# Getting ISSN info 23105 / 26806
# Getting ISSN info 23106 / 26806
# Getting ISSN info 23107 / 26806
# Getting ISSN info 23108 / 26806
# Getting ISSN info 23109 / 26806
# Getting ISSN info 23110 / 26806
# Getting ISSN info 23111 / 26806
# Getting ISSN info 23112 / 26806
# Getting ISSN info 23113 / 26806
# Getting ISSN info 23114 / 26806
# Getting ISSN info 23115 / 26806
# Getting ISSN info 23116 / 26806
# Getting ISSN info 23117 / 26806
# Getting ISSN info 23118 / 26806
# Getting ISSN info 23119 / 26806
# Getting ISSN info 23120 / 26806
# Getting ISSN info 23121 / 26806
# Getting ISSN info 23122 / 26806
# Getting ISSN info 23123 / 26806
# Getting ISSN info 23124 / 26806
# Getting ISSN info 23125 / 26806
# Getting ISSN info 23126 / 26806
# Getting ISSN info 23127 / 26806
# Getting ISSN info 23128 / 26806
# Getting ISSN info 23129 / 26806
# Getting ISSN info 23130 / 26806
# Getting ISSN info 23131 / 26806
# Getting ISSN info 23132 / 26806
# Getting ISSN info 23133 / 26806
# Getting ISSN info 23134 / 26806
# Getting ISSN info 23135 / 26806
# Getting ISSN info 23136 / 26806
# Getting ISSN info 23137 / 26806
# Getting ISSN info 23138 / 26806
# Getting ISSN info 23139 / 26806
# Getting ISSN info 23140 / 26806
# Getting ISSN info 23141 / 26806
# Getting ISSN info 23142 / 26806
# Getting ISSN info 23143 / 26806
# Getting ISSN info 23144 / 26806
# Getting ISSN info 23145 / 26806
# Getting ISSN info 23146 / 26806
# Getting ISSN info 23147 / 26806
# Getting ISSN info 23148 / 26806
# Getting ISSN info 23149 / 26806
# Getting ISSN info 23150 / 26806
# Getting ISSN info 23151 / 26806
# Getting ISSN info 23152 / 26806
# Getting ISSN info 23153 / 26806
# Getting ISSN info 23154 / 26806
# Getting ISSN info 23155 / 26806
# Getting ISSN info 23156 / 26806
# Getting ISSN info 23157 / 26806
# Getting ISSN info 23158 / 26806
# Getting ISSN info 23159 / 26806
# Getting ISSN info 23160 / 26806
# Getting ISSN info 23161 / 26806
# Getting ISSN info 23162 / 26806
# Getting ISSN info 23163 / 26806
# Getting ISSN info 23164 / 26806
# Getting ISSN info 23165 / 26806
# Getting ISSN info 23166 / 26806
# Getting ISSN info 23167 / 26806
# Getting ISSN info 23168 / 26806
# Getting ISSN info 23169 / 26806
# Getting ISSN info 23170 / 26806
# Getting ISSN info 23171 / 26806
# Getting ISSN info 23172 / 26806
# Getting ISSN info 23173 / 26806
# Getting ISSN info 23174 / 26806
# Getting ISSN info 23175 / 26806
# Getting ISSN info 23176 / 26806
# Getting ISSN info 23177 / 26806
# Getting ISSN info 23178 / 26806
# Getting ISSN info 23179 / 26806
# Getting ISSN info 23180 / 26806
# Getting ISSN info 23181 / 26806
# Getting ISSN info 23182 / 26806
# Getting ISSN info 23183 / 26806
# Getting ISSN info 23184 / 26806
# Getting ISSN info 23185 / 26806
# Getting ISSN info 23186 / 26806
# Getting ISSN info 23187 / 26806
# Getting ISSN info 23188 / 26806
# Getting ISSN info 23189 / 26806
# Getting ISSN info 23190 / 26806
# Getting ISSN info 23191 / 26806
# Getting ISSN info 23192 / 26806
# Getting ISSN info 23193 / 26806
# Getting ISSN info 23194 / 26806
# Getting ISSN info 23195 / 26806
# Getting ISSN info 23196 / 26806
# Getting ISSN info 23197 / 26806
# Getting ISSN info 23198 / 26806
# Getting ISSN info 23199 / 26806
# Getting ISSN info 23200 / 26806
# Getting ISSN info 23201 / 26806
# Getting ISSN info 23202 / 26806
# Getting ISSN info 23203 / 26806
# Getting ISSN info 23204 / 26806
# Getting ISSN info 23205 / 26806
# Getting ISSN info 23206 / 26806
# Getting ISSN info 23207 / 26806
# Getting ISSN info 23208 / 26806
# Getting ISSN info 23209 / 26806
# Getting ISSN info 23210 / 26806
# Getting ISSN info 23211 / 26806
# Getting ISSN info 23212 / 26806
# Getting ISSN info 23213 / 26806
# Getting ISSN info 23214 / 26806
# Getting ISSN info 23215 / 26806
# Getting ISSN info 23216 / 26806
# Getting ISSN info 23217 / 26806
# Getting ISSN info 23218 / 26806
# Getting ISSN info 23219 / 26806
# Getting ISSN info 23220 / 26806
# Getting ISSN info 23221 / 26806
# Getting ISSN info 23222 / 26806
# Getting ISSN info 23223 / 26806
# Getting ISSN info 23224 / 26806
# Getting ISSN info 23225 / 26806
# Getting ISSN info 23226 / 26806
# Getting ISSN info 23227 / 26806
# Getting ISSN info 23228 / 26806
# Getting ISSN info 23229 / 26806
# Getting ISSN info 23230 / 26806
# Getting ISSN info 23231 / 26806
# Getting ISSN info 23232 / 26806
# Getting ISSN info 23233 / 26806
# Getting ISSN info 23234 / 26806
# Getting ISSN info 23235 / 26806
# Getting ISSN info 23236 / 26806
# Getting ISSN info 23237 / 26806
# Getting ISSN info 23238 / 26806
# Getting ISSN info 23239 / 26806
# Getting ISSN info 23240 / 26806
# Getting ISSN info 23241 / 26806
# Getting ISSN info 23242 / 26806
# Getting ISSN info 23243 / 26806
# Getting ISSN info 23244 / 26806
# Getting ISSN info 23245 / 26806
# Getting ISSN info 23246 / 26806
# Getting ISSN info 23247 / 26806
# Getting ISSN info 23248 / 26806
# Getting ISSN info 23249 / 26806
# Getting ISSN info 23250 / 26806
# Getting ISSN info 23251 / 26806
# Getting ISSN info 23252 / 26806
# Getting ISSN info 23253 / 26806
# Getting ISSN info 23254 / 26806
# Getting ISSN info 23255 / 26806
# Getting ISSN info 23256 / 26806
# Getting ISSN info 23257 / 26806
# Getting ISSN info 23258 / 26806
# Getting ISSN info 23259 / 26806
# Getting ISSN info 23260 / 26806
# Getting ISSN info 23261 / 26806
# Getting ISSN info 23262 / 26806
# Getting ISSN info 23263 / 26806
# Getting ISSN info 23264 / 26806
# Getting ISSN info 23265 / 26806
# Getting ISSN info 23266 / 26806
# Getting ISSN info 23267 / 26806
# Getting ISSN info 23268 / 26806
# Getting ISSN info 23269 / 26806
# Getting ISSN info 23270 / 26806
# Getting ISSN info 23271 / 26806
# Getting ISSN info 23272 / 26806
# Getting ISSN info 23273 / 26806
# Getting ISSN info 23274 / 26806
# Getting ISSN info 23275 / 26806
# Getting ISSN info 23276 / 26806
# Getting ISSN info 23277 / 26806
# Getting ISSN info 23278 / 26806
# Getting ISSN info 23279 / 26806
# Getting ISSN info 23280 / 26806
# Getting ISSN info 23281 / 26806
# Getting ISSN info 23282 / 26806
# Getting ISSN info 23283 / 26806
# Getting ISSN info 23284 / 26806
# Getting ISSN info 23285 / 26806
# Getting ISSN info 23286 / 26806
# Getting ISSN info 23287 / 26806
# Getting ISSN info 23288 / 26806
# Getting ISSN info 23289 / 26806
# Getting ISSN info 23290 / 26806
# Getting ISSN info 23291 / 26806
# Getting ISSN info 23292 / 26806
# Getting ISSN info 23293 / 26806
# Getting ISSN info 23294 / 26806
# Getting ISSN info 23295 / 26806
# Getting ISSN info 23296 / 26806
# Getting ISSN info 23297 / 26806
# Getting ISSN info 23298 / 26806
# Getting ISSN info 23299 / 26806
# Getting ISSN info 23300 / 26806
# Getting ISSN info 23301 / 26806
# Getting ISSN info 23302 / 26806
# Getting ISSN info 23303 / 26806
# Getting ISSN info 23304 / 26806
# ...
# Getting ISSN info 26307 / 26806
# Getting ISSN info 26308 / 26806
# Getting ISSN info 26309 / 26806
# Getting ISSN info 26310 / 26806
# Getting ISSN info 26311 / 26806
# Getting ISSN info 26312 / 26806
# Getting ISSN info 26313 / 26806
# Getting ISSN info 26314 / 26806
# Getting ISSN info 26315 / 26806
# Getting ISSN info 26316 / 26806
# Getting ISSN info 26317 / 26806
# Getting ISSN info 26318 / 26806
# Getting ISSN info 26319 / 26806
# Getting ISSN info 26320 / 26806
# Getting ISSN info 26321 / 26806
# Getting ISSN info 26322 / 26806
# Getting ISSN info 26323 / 26806
# Getting ISSN info 26324 / 26806
# Getting ISSN info 26325 / 26806
# Getting ISSN info 26326 / 26806
# Getting ISSN info 26327 / 26806
# Getting ISSN info 26328 / 26806
# Getting ISSN info 26329 / 26806
# Getting ISSN info 26330 / 26806
# Getting ISSN info 26331 / 26806
# Getting ISSN info 26332 / 26806
# Getting ISSN info 26333 / 26806
# Getting ISSN info 26334 / 26806
# Getting ISSN info 26335 / 26806
# Getting ISSN info 26336 / 26806
# Getting ISSN info 26337 / 26806
# Getting ISSN info 26338 / 26806
# Getting ISSN info 26339 / 26806
# Getting ISSN info 26340 / 26806
# Getting ISSN info 26341 / 26806
# Getting ISSN info 26342 / 26806
# Getting ISSN info 26343 / 26806
# Getting ISSN info 26344 / 26806
# Getting ISSN info 26345 / 26806
# Getting ISSN info 26346 / 26806
# Getting ISSN info 26347 / 26806
# Getting ISSN info 26348 / 26806
# Getting ISSN info 26349 / 26806
# Getting ISSN info 26350 / 26806
# Getting ISSN info 26351 / 26806
# Getting ISSN info 26352 / 26806
# Getting ISSN info 26353 / 26806
# Getting ISSN info 26354 / 26806
# Getting ISSN info 26355 / 26806
# Getting ISSN info 26356 / 26806
# Getting ISSN info 26357 / 26806
# Getting ISSN info 26358 / 26806
# Getting ISSN info 26359 / 26806
# Getting ISSN info 26360 / 26806
# Getting ISSN info 26361 / 26806
# Getting ISSN info 26362 / 26806
# Getting ISSN info 26363 / 26806
# Getting ISSN info 26364 / 26806
# Getting ISSN info 26365 / 26806
# Getting ISSN info 26366 / 26806
# Getting ISSN info 26367 / 26806
# Getting ISSN info 26368 / 26806
# Getting ISSN info 26369 / 26806
# Getting ISSN info 26370 / 26806
# Getting ISSN info 26371 / 26806
# Getting ISSN info 26372 / 26806
# Getting ISSN info 26373 / 26806
# Getting ISSN info 26374 / 26806
# Getting ISSN info 26375 / 26806
# Getting ISSN info 26376 / 26806
# Getting ISSN info 26377 / 26806
# Getting ISSN info 26378 / 26806
# Getting ISSN info 26379 / 26806
# Getting ISSN info 26380 / 26806
# Getting ISSN info 26381 / 26806
# Getting ISSN info 26382 / 26806
# Getting ISSN info 26383 / 26806
# Getting ISSN info 26384 / 26806
# Getting ISSN info 26385 / 26806
# Getting ISSN info 26386 / 26806
# Getting ISSN info 26387 / 26806
# Getting ISSN info 26388 / 26806
# Getting ISSN info 26389 / 26806
# Getting ISSN info 26390 / 26806
# Getting ISSN info 26391 / 26806
# Getting ISSN info 26392 / 26806
# Getting ISSN info 26393 / 26806
# Getting ISSN info 26394 / 26806
# Getting ISSN info 26395 / 26806
# Getting ISSN info 26396 / 26806
# Getting ISSN info 26397 / 26806
# Getting ISSN info 26398 / 26806
# Getting ISSN info 26399 / 26806
# Getting ISSN info 26400 / 26806
# Getting ISSN info 26401 / 26806
# Getting ISSN info 26402 / 26806
# Getting ISSN info 26403 / 26806
# Getting ISSN info 26404 / 26806
# Getting ISSN info 26405 / 26806
# Getting ISSN info 26406 / 26806
# Getting ISSN info 26407 / 26806
# Getting ISSN info 26408 / 26806
# Getting ISSN info 26409 / 26806
# Getting ISSN info 26410 / 26806
# Getting ISSN info 26411 / 26806
# Getting ISSN info 26412 / 26806
# Getting ISSN info 26413 / 26806
# Getting ISSN info 26414 / 26806
# Getting ISSN info 26415 / 26806
# Getting ISSN info 26416 / 26806
# Getting ISSN info 26417 / 26806
# Getting ISSN info 26418 / 26806
# Getting ISSN info 26419 / 26806
# Getting ISSN info 26420 / 26806
# Getting ISSN info 26421 / 26806
# Getting ISSN info 26422 / 26806
# Getting ISSN info 26423 / 26806
# Getting ISSN info 26424 / 26806
# Getting ISSN info 26425 / 26806
# Getting ISSN info 26426 / 26806
# Getting ISSN info 26427 / 26806
# Getting ISSN info 26428 / 26806
# Getting ISSN info 26429 / 26806
# Getting ISSN info 26430 / 26806
# Getting ISSN info 26431 / 26806
# Getting ISSN info 26432 / 26806
# Getting ISSN info 26433 / 26806
# Getting ISSN info 26434 / 26806
# Getting ISSN info 26435 / 26806
# Getting ISSN info 26436 / 26806
# Getting ISSN info 26437 / 26806
# Getting ISSN info 26438 / 26806
# Getting ISSN info 26439 / 26806
# Getting ISSN info 26440 / 26806
# Getting ISSN info 26441 / 26806
# Getting ISSN info 26442 / 26806
# Getting ISSN info 26443 / 26806
# Getting ISSN info 26444 / 26806
# Getting ISSN info 26445 / 26806
# Getting ISSN info 26446 / 26806
# Getting ISSN info 26447 / 26806
# Getting ISSN info 26448 / 26806
# Getting ISSN info 26449 / 26806
# Getting ISSN info 26450 / 26806
# Getting ISSN info 26451 / 26806
# Getting ISSN info 26452 / 26806
# Getting ISSN info 26453 / 26806
# Getting ISSN info 26454 / 26806
# Getting ISSN info 26455 / 26806
# Getting ISSN info 26456 / 26806
# Getting ISSN info 26457 / 26806
# Getting ISSN info 26458 / 26806
# Getting ISSN info 26459 / 26806
# Getting ISSN info 26460 / 26806
# Getting ISSN info 26461 / 26806
# Getting ISSN info 26462 / 26806
# Getting ISSN info 26463 / 26806
# Getting ISSN info 26464 / 26806
# Getting ISSN info 26465 / 26806
# Getting ISSN info 26466 / 26806
# Getting ISSN info 26467 / 26806
# Getting ISSN info 26468 / 26806
# Getting ISSN info 26469 / 26806
# Getting ISSN info 26470 / 26806
# Getting ISSN info 26471 / 26806
# Getting ISSN info 26472 / 26806
# Getting ISSN info 26473 / 26806
# Getting ISSN info 26474 / 26806
# Getting ISSN info 26475 / 26806
# Getting ISSN info 26476 / 26806
# Getting ISSN info 26477 / 26806
# Getting ISSN info 26478 / 26806
# Getting ISSN info 26479 / 26806
# Getting ISSN info 26480 / 26806
# Getting ISSN info 26481 / 26806
# Getting ISSN info 26482 / 26806
# Getting ISSN info 26483 / 26806
# Getting ISSN info 26484 / 26806
# Getting ISSN info 26485 / 26806
# Getting ISSN info 26486 / 26806
# Getting ISSN info 26487 / 26806
# Getting ISSN info 26488 / 26806
# Getting ISSN info 26489 / 26806
# Getting ISSN info 26490 / 26806
# Getting ISSN info 26491 / 26806
# Getting ISSN info 26492 / 26806
# Getting ISSN info 26493 / 26806
# Getting ISSN info 26494 / 26806
# Getting ISSN info 26495 / 26806
# Getting ISSN info 26496 / 26806
# Getting ISSN info 26497 / 26806
# Getting ISSN info 26498 / 26806
# Getting ISSN info 26499 / 26806
# Getting ISSN info 26500 / 26806
# Getting ISSN info 26501 / 26806
# Getting ISSN info 26502 / 26806
# Getting ISSN info 26503 / 26806
# Getting ISSN info 26504 / 26806
# Getting ISSN info 26505 / 26806
# Getting ISSN info 26506 / 26806
# Getting ISSN info 26507 / 26806
# Getting ISSN info 26508 / 26806
# Getting ISSN info 26509 / 26806
# Getting ISSN info 26510 / 26806
# Getting ISSN info 26511 / 26806
# Getting ISSN info 26512 / 26806
# Getting ISSN info 26513 / 26806
# Getting ISSN info 26514 / 26806
# Getting ISSN info 26515 / 26806
# Getting ISSN info 26516 / 26806
# Getting ISSN info 26517 / 26806
# Getting ISSN info 26518 / 26806
# Getting ISSN info 26519 / 26806
# Getting ISSN info 26520 / 26806
# Getting ISSN info 26521 / 26806
# Getting ISSN info 26522 / 26806
# Getting ISSN info 26523 / 26806
# Getting ISSN info 26524 / 26806
# Getting ISSN info 26525 / 26806
# Getting ISSN info 26526 / 26806
# Getting ISSN info 26527 / 26806
# Getting ISSN info 26528 / 26806
# Getting ISSN info 26529 / 26806
# Getting ISSN info 26530 / 26806
# Getting ISSN info 26531 / 26806
# Getting ISSN info 26532 / 26806
# Getting ISSN info 26533 / 26806
# Getting ISSN info 26534 / 26806
# Getting ISSN info 26535 / 26806
# Getting ISSN info 26536 / 26806
# Getting ISSN info 26537 / 26806
# Getting ISSN info 26538 / 26806
# Getting ISSN info 26539 / 26806
# Getting ISSN info 26540 / 26806
# Getting ISSN info 26541 / 26806
# Getting ISSN info 26542 / 26806
# Getting ISSN info 26543 / 26806
# Getting ISSN info 26544 / 26806
# Getting ISSN info 26545 / 26806
# Getting ISSN info 26546 / 26806
# Getting ISSN info 26547 / 26806
# Getting ISSN info 26548 / 26806
# Getting ISSN info 26549 / 26806
# Getting ISSN info 26550 / 26806
# Getting ISSN info 26551 / 26806
# Getting ISSN info 26552 / 26806
# Getting ISSN info 26553 / 26806
# Getting ISSN info 26554 / 26806
# Getting ISSN info 26555 / 26806
# Getting ISSN info 26556 / 26806
# Getting ISSN info 26557 / 26806
# Getting ISSN info 26558 / 26806
# Getting ISSN info 26559 / 26806
# Getting ISSN info 26560 / 26806
# Getting ISSN info 26561 / 26806
# Getting ISSN info 26562 / 26806
# Getting ISSN info 26563 / 26806
# Getting ISSN info 26564 / 26806
# Getting ISSN info 26565 / 26806
# Getting ISSN info 26566 / 26806
# Getting ISSN info 26567 / 26806
# Getting ISSN info 26568 / 26806
# Getting ISSN info 26569 / 26806
# Getting ISSN info 26570 / 26806
# Getting ISSN info 26571 / 26806
# Getting ISSN info 26572 / 26806
# Getting ISSN info 26573 / 26806
# Getting ISSN info 26574 / 26806
# Getting ISSN info 26575 / 26806
# Getting ISSN info 26576 / 26806
# Getting ISSN info 26577 / 26806
# Getting ISSN info 26578 / 26806
# Getting ISSN info 26579 / 26806
# Getting ISSN info 26580 / 26806
# Getting ISSN info 26581 / 26806
# Getting ISSN info 26582 / 26806
# Getting ISSN info 26583 / 26806
# Getting ISSN info 26584 / 26806
# Getting ISSN info 26585 / 26806
# Getting ISSN info 26586 / 26806
# Getting ISSN info 26587 / 26806
# Getting ISSN info 26588 / 26806
# Getting ISSN info 26589 / 26806
# Getting ISSN info 26590 / 26806
# Getting ISSN info 26591 / 26806
# Getting ISSN info 26592 / 26806
# Getting ISSN info 26593 / 26806
# Getting ISSN info 26594 / 26806
# Getting ISSN info 26595 / 26806
# Getting ISSN info 26596 / 26806
# Getting ISSN info 26597 / 26806
# Getting ISSN info 26598 / 26806
# Getting ISSN info 26599 / 26806
# Getting ISSN info 26600 / 26806
# Getting ISSN info 26601 / 26806
# Getting ISSN info 26602 / 26806
# Getting ISSN info 26603 / 26806
# Getting ISSN info 26604 / 26806
# Getting ISSN info 26605 / 26806
# Getting ISSN info 26606 / 26806
# Getting ISSN info 26607 / 26806
# Getting ISSN info 26608 / 26806
# Getting ISSN info 26609 / 26806
# Getting ISSN info 26610 / 26806
# Getting ISSN info 26611 / 26806
# Getting ISSN info 26612 / 26806
# Getting ISSN info 26613 / 26806
# Getting ISSN info 26614 / 26806
# Getting ISSN info 26615 / 26806
# Getting ISSN info 26616 / 26806
# Getting ISSN info 26617 / 26806
# Getting ISSN info 26618 / 26806
# Getting ISSN info 26619 / 26806
# Getting ISSN info 26620 / 26806
# Getting ISSN info 26621 / 26806
# Getting ISSN info 26622 / 26806
# Getting ISSN info 26623 / 26806
# Getting ISSN info 26624 / 26806
# Getting ISSN info 26625 / 26806
# Getting ISSN info 26626 / 26806
# Getting ISSN info 26627 / 26806
# Getting ISSN info 26628 / 26806
# Getting ISSN info 26629 / 26806
# Getting ISSN info 26630 / 26806
# Getting ISSN info 26631 / 26806
# Getting ISSN info 26632 / 26806
# Getting ISSN info 26633 / 26806
# Getting ISSN info 26634 / 26806
# Getting ISSN info 26635 / 26806
# Getting ISSN info 26636 / 26806
# Getting ISSN info 26637 / 26806
# Getting ISSN info 26638 / 26806
# Getting ISSN info 26639 / 26806
# Getting ISSN info 26640 / 26806
# Getting ISSN info 26641 / 26806
# Getting ISSN info 26642 / 26806
# Getting ISSN info 26643 / 26806
# Getting ISSN info 26644 / 26806
# Getting ISSN info 26645 / 26806
# Getting ISSN info 26646 / 26806
# Getting ISSN info 26647 / 26806
# Getting ISSN info 26648 / 26806
# Getting ISSN info 26649 / 26806
# Getting ISSN info 26650 / 26806
# Getting ISSN info 26651 / 26806
# Getting ISSN info 26652 / 26806
# Getting ISSN info 26653 / 26806
# Getting ISSN info 26654 / 26806
# Getting ISSN info 26655 / 26806
# Getting ISSN info 26656 / 26806
# Getting ISSN info 26657 / 26806
# Getting ISSN info 26658 / 26806
# Getting ISSN info 26659 / 26806
# Getting ISSN info 26660 / 26806
# Getting ISSN info 26661 / 26806
# Getting ISSN info 26662 / 26806
# Getting ISSN info 26663 / 26806
# Getting ISSN info 26664 / 26806
# Getting ISSN info 26665 / 26806
# Getting ISSN info 26666 / 26806
# Getting ISSN info 26667 / 26806
# Getting ISSN info 26668 / 26806
# Getting ISSN info 26669 / 26806
# Getting ISSN info 26670 / 26806
# Getting ISSN info 26671 / 26806
# Getting ISSN info 26672 / 26806
# Getting ISSN info 26673 / 26806
# Getting ISSN info 26674 / 26806
# Getting ISSN info 26675 / 26806
# Getting ISSN info 26676 / 26806
# Getting ISSN info 26677 / 26806
# Getting ISSN info 26678 / 26806
# Getting ISSN info 26679 / 26806
# Getting ISSN info 26680 / 26806
# Getting ISSN info 26681 / 26806
# Getting ISSN info 26682 / 26806
# Getting ISSN info 26683 / 26806
# Getting ISSN info 26684 / 26806
# Getting ISSN info 26685 / 26806
# Getting ISSN info 26686 / 26806
# Getting ISSN info 26687 / 26806
# Getting ISSN info 26688 / 26806
# Getting ISSN info 26689 / 26806
# Getting ISSN info 26690 / 26806
# Getting ISSN info 26691 / 26806
# Getting ISSN info 26692 / 26806
# Getting ISSN info 26693 / 26806
# Getting ISSN info 26694 / 26806
# Getting ISSN info 26695 / 26806
# Getting ISSN info 26696 / 26806
# Getting ISSN info 26697 / 26806
# Getting ISSN info 26698 / 26806
# Getting ISSN info 26699 / 26806
# Getting ISSN info 26700 / 26806
# Getting ISSN info 26701 / 26806
# Getting ISSN info 26702 / 26806
# Getting ISSN info 26703 / 26806
# Getting ISSN info 26704 / 26806
# Getting ISSN info 26705 / 26806
# Getting ISSN info 26706 / 26806
# Getting ISSN info 26707 / 26806
# Getting ISSN info 26708 / 26806
# Getting ISSN info 26709 / 26806
# Getting ISSN info 26710 / 26806
# Getting ISSN info 26711 / 26806
# Getting ISSN info 26712 / 26806
# Getting ISSN info 26713 / 26806
# Getting ISSN info 26714 / 26806
# Getting ISSN info 26715 / 26806
# Getting ISSN info 26716 / 26806
# Getting ISSN info 26717 / 26806
# Getting ISSN info 26718 / 26806
# Getting ISSN info 26719 / 26806
# Getting ISSN info 26720 / 26806
# Getting ISSN info 26721 / 26806
# Getting ISSN info 26722 / 26806
# Getting ISSN info 26723 / 26806
# Getting ISSN info 26724 / 26806
# Getting ISSN info 26725 / 26806
# Getting ISSN info 26726 / 26806
# Getting ISSN info 26727 / 26806
# Getting ISSN info 26728 / 26806
# Getting ISSN info 26729 / 26806
# Getting ISSN info 26730 / 26806
# Getting ISSN info 26731 / 26806
# Getting ISSN info 26732 / 26806
# Getting ISSN info 26733 / 26806
# Getting ISSN info 26734 / 26806
# Getting ISSN info 26735 / 26806
# Getting ISSN info 26736 / 26806
# Getting ISSN info 26737 / 26806
# Getting ISSN info 26738 / 26806
# Getting ISSN info 26739 / 26806
# Getting ISSN info 26740 / 26806
# Getting ISSN info 26741 / 26806
# Getting ISSN info 26742 / 26806
# Getting ISSN info 26743 / 26806
# Getting ISSN info 26744 / 26806
# Getting ISSN info 26745 / 26806
# Getting ISSN info 26746 / 26806
# Getting ISSN info 26747 / 26806
# Getting ISSN info 26748 / 26806
# Getting ISSN info 26749 / 26806
# Getting ISSN info 26750 / 26806
# Getting ISSN info 26751 / 26806
# Getting ISSN info 26752 / 26806
# Getting ISSN info 26753 / 26806
# Getting ISSN info 26754 / 26806
# Getting ISSN info 26755 / 26806
# Getting ISSN info 26756 / 26806
# Getting ISSN info 26757 / 26806
# Getting ISSN info 26758 / 26806
# Getting ISSN info 26759 / 26806
# Getting ISSN info 26760 / 26806
# Getting ISSN info 26761 / 26806
# Getting ISSN info 26762 / 26806
# Getting ISSN info 26763 / 26806
# Getting ISSN info 26764 / 26806
# Getting ISSN info 26765 / 26806
# Getting ISSN info 26766 / 26806
# Getting ISSN info 26767 / 26806
# Getting ISSN info 26768 / 26806
# Getting ISSN info 26769 / 26806
# Getting ISSN info 26770 / 26806
# Getting ISSN info 26771 / 26806
# Getting ISSN info 26772 / 26806
# Getting ISSN info 26773 / 26806
# Getting ISSN info 26774 / 26806
# Getting ISSN info 26775 / 26806
# Getting ISSN info 26776 / 26806
# Getting ISSN info 26777 / 26806
# Getting ISSN info 26778 / 26806
# Getting ISSN info 26779 / 26806
# Getting ISSN info 26780 / 26806
# Getting ISSN info 26781 / 26806
# Getting ISSN info 26782 / 26806
# Getting ISSN info 26783 / 26806
# Getting ISSN info 26784 / 26806
# Getting ISSN info 26785 / 26806
# Getting ISSN info 26786 / 26806
# Getting ISSN info 26787 / 26806
# Getting ISSN info 26788 / 26806
# Getting ISSN info 26789 / 26806
# Getting ISSN info 26790 / 26806
# Getting ISSN info 26791 / 26806
# Getting ISSN info 26792 / 26806
# Getting ISSN info 26793 / 26806
# Getting ISSN info 26794 / 26806
# Getting ISSN info 26795 / 26806
# Getting ISSN info 26796 / 26806
# Getting ISSN info 26797 / 26806
# Getting ISSN info 26798 / 26806
# Getting ISSN info 26799 / 26806
# Getting ISSN info 26800 / 26806
# Getting ISSN info 26801 / 26806
# Getting ISSN info 26802 / 26806
# Getting ISSN info 26803 / 26806
# Getting ISSN info 26804 / 26806
# Getting ISSN info 26805 / 26806
# Getting ISSN info 26806 / 26806

# %%
df.to_csv("/content/drive/MyDrive/checkpoint_3_df.csv", encoding='utf-8', index=False)

# %%
# This should function too, yet I don't know if it's ok to bypass HTTP 403: "Forbidden" by changing the 'User-Agent' ... kinda the only way to get the full text/html of the article ...

# def get_pmc_data (row):
#   if ( row["pmc"] == None ):
#     return None

#   from urllib.request import Request, urlopen
#   site = "https://pmc.ncbi.nlm.nih.gov/articles/PMC"+row["pmc"]+"/"
#   hdr = {'User-Agent': 'Mozilla/5.0'} # Eighter this, or it detects that it is not a regular browser and restricts access ... Is this a problem?
#   req = Request(site,headers=hdr)
#   page = urlopen(req)
#   soup = BeautifulSoup(page, 'html.parser')

#   # container = soup.find(attrs={"class" : "body main-article-body"}) # the article without the title and so on ...
#   article = soup.find("article")
#   return article

# def get_pmc_data_html (row):
#   article = get_pmc_data(row)
#   if ( article != None ):
#     return str(article)
#   else:
#     return None

# def get_pmc_data_text (row):
#   article = get_pmc_data(row)
#   if ( article != None ):
#     return article.get_text()
#   else:
#     return None

# df["full_article_html"]=df.apply(get_pmc_data_html, axis=1)
# df["full_article_text"]=df.apply(get_pmc_data_text, axis=1)

# %%
# Remove duplicated (not sure if necessary)

df = df.astype(str)
df.drop_duplicates(keep=False, inplace=True)

# %%
# Saving only PMID/citation data to a CSV file. This file is meant for creating a citation network ...
# df[["pmid", "references"]].to_csv("/content/drive/MyDrive/citations.csv", encoding='utf-8', index=False)

# Saving the whole dataframe data to a CSV too ...
df.to_csv("/content/drive/MyDrive/extracted_features.csv", encoding='utf-8', index=False)

# %%
# Printing the full article data (disable if you have tons of articles) ...

# def print_row ( iter ):
#   print("{:<20} {:<20}".format("Attribute", "Value")); print("-" * 41)
#   for i in range(0, len( df.columns ) ):
#     print("{:<20} {:<20}".format(str(df.columns[i]), str(df.iloc[iter].iloc[i])) )
#   print("\n\n")

# for k in range(0, df.shape[0] ):
#   print_row(k)

# %%
# So, those are the features that were kept so far ...

print(df.columns.values)

# %%
# This adds the columns of "df" to "csv_df" without adding any data ... not necessary, it is done when data is added ...

# for column in df.columns.values:
#   if ( column in [ "pmid", "abstract", "title" ] ):
#     continue
#   csv_df[ column ] = None

# %%
def get_data_by_pmid(row):
  pmid=row["PMID"]
  row_iter = df.index[df['pmid'] == str(pmid)].tolist()[0]
  for column in df.columns.values:
    if ( column in [ "pmid", "abstract", "title" ] ):
      continue
    row[ column ] = df.loc[ row_iter ][ column ]
  return row

csv_df = csv_df.apply(get_data_by_pmid, axis=1)

# %%
# Save the newly aquired information to flies that match the source data filenames, withing the "Feature_extraction_results" folder

directory="/content/drive/MyDrive/Feature_extraction_results"
if not os.path.exists(directory):
    os.makedirs(directory)

filenames = csv_df['Filename'].unique()
for filename in filenames:
  df_filename = csv_df.loc[csv_df['Filename'] == filename]
  df_filename = df_filename.drop('Filename', axis=1)
  df_filename.to_csv("/content/drive/MyDrive/Feature_extraction_results/" + filename, encoding='utf-8', index=False)

# %%
# I did not code this and it seemed interesting ... why is there a try/catch? are not all reviews public? might some have been deleted?

# num = 0
# while num < CD012768.shape[0]:
#   pmid = pmids[num]
#   try:
#     article = fetch.article_by_pmid(pmid)
#     titles[pmid] = article.title
#     abstracts[pmid] = article.abstract
#   except:
#     pass
#   else:
#     print(num)
#     num += 1
